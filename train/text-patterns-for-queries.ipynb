# %%
import spacy
import random
import datetime
import json
import math
import dateutil.parser
from spacy.matcher import Matcher

largenlp = spacy.load('en_core_web_lg')

# %% [markdown]
# ### JSON Content utlities for the TMDB corpus

# %%
#Iterate through the movies
def rawTmdbMovies(filename):
    return json.load(open(filename))


def writeTmdmMovies(rawMoviesJson, path):
    with open(path, 'w') as f:
        json.dump(rawMoviesJson, f)

def tmdbMovies(filename="../tmdb.json"):
    tmdbMovies = rawTmdbMovies(filename)
    for movieId, tmdbMovie in tmdbMovies.items():
        yield (movieId, tmdbMovie)

def indexableMovies(filename="../tmdb.json"):
    """ Generates TMDB movies, similar to how ES Bulk indexing
        uses a generator to generate bulk index/update actions """
    for movieId, tmdbMovie in tmdbMovies(filename):
        try:
            releaseDate = None
            if 'release_date' in tmdbMovie and len(tmdbMovie['release_date']) > 0:
                releaseDate = tmdbMovie['release_date'] + 'T00:00:00Z'

            yield {'id': movieId,
                   'title': tmdbMovie['title'],
                   'overview': tmdbMovie['overview'],
                   'tagline': tmdbMovie['tagline'],
                   'directors': [director['name'] for director in tmdbMovie['directors']],
                   'cast': [castMember['name'] for castMember in tmdbMovie['cast']],
                   'genres': [genre['name'] for genre in tmdbMovie['genres']],
                   'release_date': releaseDate,
                   'vote_average': tmdbMovie['vote_average'] if 'vote_average' in tmdbMovie else None,
                   'vote_count': int(tmdbMovie['vote_count']) if 'vote_count' in tmdbMovie else None,
                   'location_entities': tmdbMovie['location_entities'] if 'location_entities' in tmdbMovie else [],
                   'location': tmdbMovie['location'] if 'location' in tmdbMovie else [],
                   'location_city': tmdbMovie['location_city'] if 'location_city' in tmdbMovie else [],
                   'location_state': tmdbMovie['location_state'] if 'location_state' in tmdbMovie else [],
                   'location_country': tmdbMovie['location_country'] if 'location_country' in tmdbMovie else [],
                   }
        except KeyError as k: # Ignore any movies missing these attributes
            continue

# %% [markdown]
# ### Get the overview texts
#
# We're going to use the overview text to train lowercase entities for our queries.
#
# This is free training data!  We'll take the entities from the true-cased overview text, and apply them to the lower-cased text, and train a new model

# %%
def overviews(filename="../tmdb.json"):
    #Get all the overviews
    texts = []
    for movie_id, movie in tmdbMovies(filename=filename):
        if "overview" in movie and isinstance(movie["overview"], str) and len(movie["overview"]):
            texts.append(movie["overview"])
    return texts

# %%
overview_texts = overviews()

# %% [markdown]
# ## Use Lexico-syntactic patterns
#
# Lexico-syntactic patterns use parts-of-speech to look for common structures in text.  For example a verb followed by a proper noun.  They can give good results but are very basic and only work when you know the patterns ahead of time.  For more information on this topic, see 'Hearst Patterns' named after Marti Hearst, who first used the idea in the 1980s to expand early versions of wordnet.

# %%
def find_pattern(texts,name,pattern):
    matcher = Matcher(largenlp.vocab)
    matcher.add(name, None, pattern)
    matches = []
    for doc in largenlp.pipe(texts):
        for match in matcher(doc):
            example = [tok.text for tok in doc[match[1]:match[2]]]
            matches.append(example)
    return matches

# %%
verbpnouns = find_pattern(overview_texts,"VerbPNouns",[
        {"POS": "VERB"}, 
        {"LABEL": ["GPE","PERSON"]},
        {"LABEL": ["GPE","PERSON"],"OP":"+"}
    ]
)

# %%
verbpnouns
# Out:
# [['share', 'a', 'Christmas'],
#  ['share', 'a', 'Christmas', 'meal'],
#  ['share', 'a', 'Christmas', 'meal', ','],
#  ['share', 'a', 'Christmas', 'meal', ',', 'swapping'],
#  ['share', 'a', 'Christmas', 'meal', ',', 'swapping', 'creepy'],
#  ['share', 'a', 'Christmas', 'meal', ',', 'swapping', 'creepy', 'tales'],
#  ['swapping', 'creepy', 'tales'],
#  ['share', 'a', 'Christmas', 'meal', ',', 'swapping', 'creepy', 'tales', 'of'],
#  ['swapping', 'creepy', 'tales', 'of'],
#  ['share',
#   'a',
#   'Christmas',
#   'meal',
#   ',',
#   'swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their'],
#  ['swapping', 'creepy', 'tales', 'of', 'their'],
#  ['share',
#   'a',
#   'Christmas',
#   'meal',
#   ',',
#   'swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier'],
#  ['swapping', 'creepy', 'tales', 'of', 'their', 'earlier'],
#  ['share',
#   'a',
#   'Christmas',
#   'meal',
#   ',',
#   'swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives'],
#  ['swapping', 'creepy', 'tales', 'of', 'their', 'earlier', 'lives'],
#  ['share',
#   'a',
#   'Christmas',
#   'meal',
#   ',',
#   'swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in'],
#  ['swapping', 'creepy', 'tales', 'of', 'their', 'earlier', 'lives', 'in'],
#  ['share',
#   'a',
#   'Christmas',
#   'meal',
#   ',',
#   'swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the'],
#  ['swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the'],
#  ['share',
#   'a',
#   'Christmas',
#   'meal',
#   ',',
#   'swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside'],
#  ['swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside'],
#  ['share',
#   'a',
#   'Christmas',
#   'meal',
#   ',',
#   'swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world'],
#  ['swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world'],
#  ['share',
#   'a',
#   'Christmas',
#   'meal',
#   ',',
#   'swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.'],
#  ['swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.'],
#  ['share',
#   'a',
#   'Christmas',
#   'meal',
#   ',',
#   'swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt'],
#  ['swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt'],
#  ['share',
#   'a',
#   'Christmas',
#   'meal',
#   ',',
#   'swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is'],
#  ['swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is'],
#  ['share',
#   'a',
#   'Christmas',
#   'meal',
#   ',',
#   'swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a'],
#  ['swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a'],
#  ['share',
#   'a',
#   'Christmas',
#   'meal',
#   ',',
#   'swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic'],
#  ['swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic'],
#  ['is', 'a', 'charismatic'],
#  ['share',
#   'a',
#   'Christmas',
#   'meal',
#   ',',
#   'swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American'],
#  ['swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American'],
#  ['is', 'a', 'charismatic', 'American'],
#  ['share',
#   'a',
#   'Christmas',
#   'meal',
#   ',',
#   'swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying'],
#  ['swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying'],
#  ['is', 'a', 'charismatic', 'American', 'trying'],
#  ['share',
#   'a',
#   'Christmas',
#   'meal',
#   ',',
#   'swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to'],
#  ['swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to'],
#  ['is', 'a', 'charismatic', 'American', 'trying', 'to'],
#  ['share',
#   'a',
#   'Christmas',
#   'meal',
#   ',',
#   'swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring'],
#  ['swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring'],
#  ['is', 'a', 'charismatic', 'American', 'trying', 'to', 'bring'],
#  ['trying', 'to', 'bring'],
#  ['share',
#   'a',
#   'Christmas',
#   'meal',
#   ',',
#   'swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the'],
#  ['swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the'],
#  ['is', 'a', 'charismatic', 'American', 'trying', 'to', 'bring', 'the'],
#  ['trying', 'to', 'bring', 'the'],
#  ['share',
#   'a',
#   'Christmas',
#   'meal',
#   ',',
#   'swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved'],
#  ['swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved'],
#  ['is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved'],
#  ['trying', 'to', 'bring', 'the', 'reserved'],
#  ['bring', 'the', 'reserved'],
#  ['share',
#   'a',
#   'Christmas',
#   'meal',
#   ',',
#   'swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ','],
#  ['swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ','],
#  ['is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ','],
#  ['trying', 'to', 'bring', 'the', 'reserved', ','],
#  ['bring', 'the', 'reserved', ','],
#  ['share',
#   'a',
#   'Christmas',
#   'meal',
#   ',',
#   'swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive'],
#  ['swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive'],
#  ['is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive'],
#  ['trying', 'to', 'bring', 'the', 'reserved', ',', 'secretive'],
#  ['bring', 'the', 'reserved', ',', 'secretive'],
#  ['reserved', ',', 'secretive'],
#  ['share',
#   'a',
#   'Christmas',
#   'meal',
#   ',',
#   'swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter'],
#  ['swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter'],
#  ['is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter'],
#  ['trying', 'to', 'bring', 'the', 'reserved', ',', 'secretive', 'Potter'],
#  ['bring', 'the', 'reserved', ',', 'secretive', 'Potter'],
#  ['reserved', ',', 'secretive', 'Potter'],
#  ['share',
#   'a',
#   'Christmas',
#   'meal',
#   ',',
#   'swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out'],
#  ['swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out'],
#  ['is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out'],
#  ['trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out'],
#  ['bring', 'the', 'reserved', ',', 'secretive', 'Potter', 'out'],
#  ['reserved', ',', 'secretive', 'Potter', 'out'],
#  ['share',
#   'a',
#   'Christmas',
#   'meal',
#   ',',
#   'swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of'],
#  ['swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of'],
#  ['is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of'],
#  ['trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of'],
#  ['bring', 'the', 'reserved', ',', 'secretive', 'Potter', 'out', 'of'],
#  ['reserved', ',', 'secretive', 'Potter', 'out', 'of'],
#  ['share',
#   'a',
#   'Christmas',
#   'meal',
#   ',',
#   'swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his'],
#  ['swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his'],
#  ['is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his'],
#  ['trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his'],
#  ['bring', 'the', 'reserved', ',', 'secretive', 'Potter', 'out', 'of', 'his'],
#  ['reserved', ',', 'secretive', 'Potter', 'out', 'of', 'his'],
#  ['share',
#   'a',
#   'Christmas',
#   'meal',
#   ',',
#   'swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell'],
#  ['swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell'],
#  ['is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell'],
#  ['trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell'],
#  ['bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell'],
#  ['reserved', ',', 'secretive', 'Potter', 'out', 'of', 'his', 'shell'],
#  ['share',
#   'a',
#   'Christmas',
#   'meal',
#   ',',
#   'swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.'],
#  ['swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.'],
#  ['is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.'],
#  ['trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.'],
#  ['bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.'],
#  ['reserved', ',', 'secretive', 'Potter', 'out', 'of', 'his', 'shell', '.'],
#  ['share',
#   'a',
#   'Christmas',
#   'meal',
#   ',',
#   'swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But'],
#  ['swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But'],
#  ['is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But'],
#  ['trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But'],
#  ['bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But'],
#  ['reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But'],
#  ['share',
#   'a',
#   'Christmas',
#   'meal',
#   ',',
#   'swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are'],
#  ['swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are'],
#  ['is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are'],
#  ['trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are'],
#  ['bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are'],
#  ['reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are'],
#  ['share',
#   'a',
#   'Christmas',
#   'meal',
#   ',',
#   'swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both'],
#  ['swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both'],
#  ['is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both'],
#  ['trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both'],
#  ['bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both'],
#  ['reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both'],
#  ['share',
#   'a',
#   'Christmas',
#   'meal',
#   ',',
#   'swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men'],
#  ['swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men'],
#  ['is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men'],
#  ['trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men'],
#  ['bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men'],
#  ['reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men'],
#  ['are', 'both', 'men'],
#  ['share',
#   'a',
#   'Christmas',
#   'meal',
#   ',',
#   'swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who'],
#  ['swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who'],
#  ['is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who'],
#  ['trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who'],
#  ['bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who'],
#  ['reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who'],
#  ['are', 'both', 'men', 'who'],
#  ['share',
#   'a',
#   'Christmas',
#   'meal',
#   ',',
#   'swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they'],
#  ['swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they'],
#  ['is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they'],
#  ['trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they'],
#  ['bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they'],
#  ['reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they'],
#  ['are', 'both', 'men', 'who', 'they'],
#  ['share',
#   'a',
#   'Christmas',
#   'meal',
#   ',',
#   'swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear'],
#  ['swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear'],
#  ['is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear'],
#  ['trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear'],
#  ['bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear'],
#  ['reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear'],
#  ['are', 'both', 'men', 'who', 'they', 'appear'],
#  ['share',
#   'a',
#   'Christmas',
#   'meal',
#   ',',
#   'swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to'],
#  ['swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to'],
#  ['is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to'],
#  ['trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to'],
#  ['bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to'],
#  ['reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to'],
#  ['are', 'both', 'men', 'who', 'they', 'appear', 'to'],
#  ['share',
#   'a',
#   'Christmas',
#   'meal',
#   ',',
#   'swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be'],
#  ['swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be'],
#  ['is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be'],
#  ['trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be'],
#  ['bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be'],
#  ['reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be'],
#  ['are', 'both', 'men', 'who', 'they', 'appear', 'to', 'be'],
#  ['appear', 'to', 'be'],
#  ['share',
#   'a',
#   'Christmas',
#   'meal',
#   ',',
#   'swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be',
#   '?'],
#  ['swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be',
#   '?'],
#  ['is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be',
#   '?'],
#  ['trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be',
#   '?'],
#  ['bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be',
#   '?'],
#  ['reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be',
#   '?'],
#  ['are', 'both', 'men', 'who', 'they', 'appear', 'to', 'be', '?'],
#  ['appear', 'to', 'be', '?'],
#  ['share',
#   'a',
#   'Christmas',
#   'meal',
#   ',',
#   'swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be',
#   '?',
#   'A'],
#  ['swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be',
#   '?',
#   'A'],
#  ['is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be',
#   '?',
#   'A'],
#  ['trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be',
#   '?',
#   'A'],
#  ['bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be',
#   '?',
#   'A'],
#  ['reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be',
#   '?',
#   'A'],
#  ['are', 'both', 'men', 'who', 'they', 'appear', 'to', 'be', '?', 'A'],
#  ['appear', 'to', 'be', '?', 'A'],
#  ['be', '?', 'A'],
#  ['share',
#   'a',
#   'Christmas',
#   'meal',
#   ',',
#   'swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be',
#   '?',
#   'A',
#   'woman'],
#  ['swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be',
#   '?',
#   'A',
#   'woman'],
#  ['is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be',
#   '?',
#   'A',
#   'woman'],
#  ['trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be',
#   '?',
#   'A',
#   'woman'],
#  ['bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be',
#   '?',
#   'A',
#   'woman'],
#  ['reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be',
#   '?',
#   'A',
#   'woman'],
#  ['are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be',
#   '?',
#   'A',
#   'woman'],
#  ['appear', 'to', 'be', '?', 'A', 'woman'],
#  ['be', '?', 'A', 'woman'],
#  ['share',
#   'a',
#   'Christmas',
#   'meal',
#   ',',
#   'swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be',
#   '?',
#   'A',
#   'woman',
#   'gets'],
#  ['swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be',
#   '?',
#   'A',
#   'woman',
#   'gets'],
#  ['is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be',
#   '?',
#   'A',
#   'woman',
#   'gets'],
#  ['trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be',
#   '?',
#   'A',
#   'woman',
#   'gets'],
#  ['bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be',
#   '?',
#   'A',
#   'woman',
#   'gets'],
#  ['reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be',
#   '?',
#   'A',
#   'woman',
#   'gets'],
#  ['are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be',
#   '?',
#   'A',
#   'woman',
#   'gets'],
#  ['appear', 'to', 'be', '?', 'A', 'woman', 'gets'],
#  ['be', '?', 'A', 'woman', 'gets'],
#  ['share',
#   'a',
#   'Christmas',
#   'meal',
#   ',',
#   'swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be',
#   '?',
#   'A',
#   'woman',
#   'gets',
#   'thrust'],
#  ['swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be',
#   '?',
#   'A',
#   'woman',
#   'gets',
#   'thrust'],
#  ['is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be',
#   '?',
#   'A',
#   'woman',
#   'gets',
#   'thrust'],
#  ['trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be',
#   '?',
#   'A',
#   'woman',
#   'gets',
#   'thrust'],
#  ['bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be',
#   '?',
#   'A',
#   'woman',
#   'gets',
#   'thrust'],
#  ['reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be',
#   '?',
#   'A',
#   'woman',
#   'gets',
#   'thrust'],
#  ['are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be',
#   '?',
#   'A',
#   'woman',
#   'gets',
#   'thrust'],
#  ['appear', 'to', 'be', '?', 'A', 'woman', 'gets', 'thrust'],
#  ['be', '?', 'A', 'woman', 'gets', 'thrust'],
#  ['share',
#   'a',
#   'Christmas',
#   'meal',
#   ',',
#   'swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be',
#   '?',
#   'A',
#   'woman',
#   'gets',
#   'thrust',
#   'into'],
#  ['swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be',
#   '?',
#   'A',
#   'woman',
#   'gets',
#   'thrust',
#   'into'],
#  ['is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be',
#   '?',
#   'A',
#   'woman',
#   'gets',
#   'thrust',
#   'into'],
#  ['trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be',
#   '?',
#   'A',
#   'woman',
#   'gets',
#   'thrust',
#   'into'],
#  ['bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be',
#   '?',
#   'A',
#   'woman',
#   'gets',
#   'thrust',
#   'into'],
#  ['reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be',
#   '?',
#   'A',
#   'woman',
#   'gets',
#   'thrust',
#   'into'],
#  ['are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be',
#   '?',
#   'A',
#   'woman',
#   'gets',
#   'thrust',
#   'into'],
#  ['appear', 'to', 'be', '?', 'A', 'woman', 'gets', 'thrust', 'into'],
#  ['be', '?', 'A', 'woman', 'gets', 'thrust', 'into'],
#  ['gets', 'thrust', 'into'],
#  ['share',
#   'a',
#   'Christmas',
#   'meal',
#   ',',
#   'swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be',
#   '?',
#   'A',
#   'woman',
#   'gets',
#   'thrust',
#   'into',
#   'a'],
#  ['swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be',
#   '?',
#   'A',
#   'woman',
#   'gets',
#   'thrust',
#   'into',
#   'a'],
#  ['is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be',
#   '?',
#   'A',
#   'woman',
#   'gets',
#   'thrust',
#   'into',
#   'a'],
#  ['trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be',
#   '?',
#   'A',
#   'woman',
#   'gets',
#   'thrust',
#   'into',
#   'a'],
#  ['bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be',
#   '?',
#   'A',
#   'woman',
#   'gets',
#   'thrust',
#   'into',
#   'a'],
#  ['reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be',
#   '?',
#   'A',
#   'woman',
#   'gets',
#   'thrust',
#   'into',
#   'a'],
#  ['are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be',
#   '?',
#   'A',
#   'woman',
#   'gets',
#   'thrust',
#   'into',
#   'a'],
#  ['appear', 'to', 'be', '?', 'A', 'woman', 'gets', 'thrust', 'into', 'a'],
#  ['be', '?', 'A', 'woman', 'gets', 'thrust', 'into', 'a'],
#  ['gets', 'thrust', 'into', 'a'],
#  ['share',
#   'a',
#   'Christmas',
#   'meal',
#   ',',
#   'swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be',
#   '?',
#   'A',
#   'woman',
#   'gets',
#   'thrust',
#   'into',
#   'a',
#   'nightmarish'],
#  ['swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be',
#   '?',
#   'A',
#   'woman',
#   'gets',
#   'thrust',
#   'into',
#   'a',
#   'nightmarish'],
#  ['is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be',
#   '?',
#   'A',
#   'woman',
#   'gets',
#   'thrust',
#   'into',
#   'a',
#   'nightmarish'],
#  ['trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be',
#   '?',
#   'A',
#   'woman',
#   'gets',
#   'thrust',
#   'into',
#   'a',
#   'nightmarish'],
#  ['bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be',
#   '?',
#   'A',
#   'woman',
#   'gets',
#   'thrust',
#   'into',
#   'a',
#   'nightmarish'],
#  ['reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be',
#   '?',
#   'A',
#   'woman',
#   'gets',
#   'thrust',
#   'into',
#   'a',
#   'nightmarish'],
#  ['are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be',
#   '?',
#   'A',
#   'woman',
#   'gets',
#   'thrust',
#   'into',
#   'a',
#   'nightmarish'],
#  ['appear',
#   'to',
#   'be',
#   '?',
#   'A',
#   'woman',
#   'gets',
#   'thrust',
#   'into',
#   'a',
#   'nightmarish'],
#  ['be', '?', 'A', 'woman', 'gets', 'thrust', 'into', 'a', 'nightmarish'],
#  ['gets', 'thrust', 'into', 'a', 'nightmarish'],
#  ['share',
#   'a',
#   'Christmas',
#   'meal',
#   ',',
#   'swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be',
#   '?',
#   'A',
#   'woman',
#   'gets',
#   'thrust',
#   'into',
#   'a',
#   'nightmarish',
#   'world'],
#  ['swapping',
#   'creepy',
#   'tales',
#   'of',
#   'their',
#   'earlier',
#   'lives',
#   'in',
#   'the',
#   'outside',
#   'world',
#   '.',
#   'Matt',
#   'is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be',
#   '?',
#   'A',
#   'woman',
#   'gets',
#   'thrust',
#   'into',
#   'a',
#   'nightmarish',
#   'world'],
#  ['is',
#   'a',
#   'charismatic',
#   'American',
#   'trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be',
#   '?',
#   'A',
#   'woman',
#   'gets',
#   'thrust',
#   'into',
#   'a',
#   'nightmarish',
#   'world'],
#  ['trying',
#   'to',
#   'bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be',
#   '?',
#   'A',
#   'woman',
#   'gets',
#   'thrust',
#   'into',
#   'a',
#   'nightmarish',
#   'world'],
#  ['bring',
#   'the',
#   'reserved',
#   ',',
#   'secretive',
#   'Potter',
#   'out',
#   'of',
#   'his',
#   'shell',
#   '.',
#   'But',
#   'are',
#   'both',
#   'men',
#   'who',
#   'they',
#   'appear',
#   'to',
#   'be',
#   '?',
# ...
#   'India',
#   'with',
#   'a',
#   'mission',
#   'at',
#   'his',
#   'hands',
#   ',',
#   'to',
#   'claim',
#   'his',
#   'lady',
#   'love',
#   'under',
#   'the',
#   'noses',
#   'of',
#   'her',
#   'whole',
#   'family',
#   '.',
#   'Thus',
#   'begins'],
#  ['left',
#   'for',
#   'India',
#   'to',
#   'be',
#   'married',
#   'to',
#   'her',
#   'childhood',
#   'fiancé',
#   '.',
#   'Raj',
#   'leaves',
#   'for',
#   'India',
#   'with',
#   'a',
#   'mission',
#   'at',
#   'his',
#   'hands',
#   ',',
#   'to',
#   'claim',
#   'his',
#   'lady',
#   'love',
#   'under',
#   'the',
#   'noses',
#   'of',
#   'her',
#   'whole',
#   'family',
#   '.',
#   'Thus',
#   'begins'],
#  ['be',
#   'married',
#   'to',
#   'her',
#   'childhood',
#   'fiancé',
#   '.',
#   'Raj',
#   'leaves',
#   'for',
#   'India',
#   'with',
#   'a',
#   'mission',
#   'at',
#   'his',
#   'hands',
#   ',',
#   'to',
#   'claim',
#   'his',
#   'lady',
#   'love',
#   'under',
#   'the',
#   'noses',
#   'of',
#   'her',
#   'whole',
#   'family',
#   '.',
#   'Thus',
#   'begins'],
#  ['leaves',
#   'for',
#   'India',
#   'with',
#   'a',
#   'mission',
#   'at',
#   'his',
#   'hands',
#   ',',
#   'to',
#   'claim',
#   'his',
#   'lady',
#   'love',
#   'under',
#   'the',
#   'noses',
#   'of',
#   'her',
#   'whole',
#   'family',
#   '.',
#   'Thus',
#   'begins'],
#  ['claim',
#   'his',
#   'lady',
#   'love',
#   'under',
#   'the',
#   'noses',
#   'of',
#   'her',
#   'whole',
#   'family',
#   '.',
#   'Thus',
#   'begins'],
#  ['is',
#   'a',
#   'rich',
#   ',',
#   'carefree',
#   ',',
#   'happy',
#   '-',
#   'go',
#   '-',
#   'lucky',
#   'second',
#   'generation',
#   'NRI',
#   '.',
#   'Simran',
#   'is',
#   'the',
#   'daughter',
#   'of',
#   'Chaudhary',
#   'Baldev',
#   'Singh',
#   ',',
#   'who',
#   'in',
#   'spite',
#   'of',
#   'being',
#   'an',
#   'NRI',
#   'is',
#   'very',
#   'strict',
#   'about',
#   'adherence',
#   'to',
#   'Indian',
#   'values',
#   '.',
#   'Simran',
#   'has',
#   'left',
#   'for',
#   'India',
#   'to',
#   'be',
#   'married',
#   'to',
#   'her',
#   'childhood',
#   'fiancé',
#   '.',
#   'Raj',
#   'leaves',
#   'for',
#   'India',
#   'with',
#   'a',
#   'mission',
#   'at',
#   'his',
#   'hands',
#   ',',
#   'to',
#   'claim',
#   'his',
#   'lady',
#   'love',
#   'under',
#   'the',
#   'noses',
#   'of',
#   'her',
#   'whole',
#   'family',
#   '.',
#   'Thus',
#   'begins',
#   'a'],
#  ['go',
#   '-',
#   'lucky',
#   'second',
#   'generation',
#   'NRI',
#   '.',
#   'Simran',
#   'is',
#   'the',
#   'daughter',
#   'of',
#   'Chaudhary',
#   'Baldev',
#   'Singh',
#   ',',
#   'who',
#   'in',
#   'spite',
#   'of',
#   'being',
#   'an',
#   'NRI',
#   'is',
#   'very',
#   'strict',
#   'about',
#   'adherence',
#   'to',
#   'Indian',
#   'values',
#   '.',
#   'Simran',
#   'has',
#   'left',
#   'for',
#   'India',
#   'to',
#   'be',
#   'married',
#   'to',
#   'her',
#   'childhood',
#   'fiancé',
#   '.',
#   'Raj',
#   'leaves',
#   'for',
#   'India',
#   'with',
#   'a',
#   'mission',
#   'at',
#   'his',
#   'hands',
#   ',',
#   'to',
#   'claim',
#   'his',
#   'lady',
#   'love',
#   'under',
#   'the',
#   'noses',
#   'of',
#   'her',
#   'whole',
#   'family',
#   '.',
#   'Thus',
#   'begins',
#   'a'],
#  ['is',
#   'the',
#   'daughter',
#   'of',
#   'Chaudhary',
#   'Baldev',
#   'Singh',
#   ',',
#   'who',
#   'in',
#   'spite',
#   'of',
#   'being',
#   'an',
#   'NRI',
#   'is',
#   'very',
#   'strict',
#   'about',
#   'adherence',
#   'to',
#   'Indian',
#   'values',
#   '.',
#   'Simran',
#   'has',
#   'left',
#   'for',
#   'India',
#   'to',
#   'be',
#   'married',
#   'to',
#   'her',
#   'childhood',
#   'fiancé',
#   '.',
#   'Raj',
#   'leaves',
#   'for',
#   'India',
#   'with',
#   'a',
#   'mission',
#   'at',
#   'his',
#   'hands',
#   ',',
#   'to',
#   'claim',
#   'his',
#   'lady',
#   'love',
#   'under',
#   'the',
#   'noses',
#   'of',
#   'her',
#   'whole',
#   'family',
#   '.',
#   'Thus',
#   'begins',
#   'a'],
#  ['being',
#   'an',
#   'NRI',
#   'is',
#   'very',
#   'strict',
#   'about',
#   'adherence',
#   'to',
#   'Indian',
#   'values',
#   '.',
#   'Simran',
#   'has',
#   'left',
#   'for',
#   'India',
#   'to',
#   'be',
#   'married',
#   'to',
#   'her',
#   'childhood',
#   'fiancé',
#   '.',
#   'Raj',
#   'leaves',
#   'for',
#   'India',
#   'with',
#   'a',
#   'mission',
#   'at',
#   'his',
#   'hands',
#   ',',
#   'to',
#   'claim',
#   'his',
#   'lady',
#   'love',
#   'under',
#   'the',
#   'noses',
#   'of',
#   'her',
#   'whole',
#   'family',
#   '.',
#   'Thus',
#   'begins',
#   'a'],
#  ['is',
#   'very',
#   'strict',
#   'about',
#   'adherence',
#   'to',
#   'Indian',
#   'values',
#   '.',
#   'Simran',
#   'has',
#   'left',
#   'for',
#   'India',
#   'to',
#   'be',
#   'married',
#   'to',
#   'her',
#   'childhood',
#   'fiancé',
#   '.',
#   'Raj',
#   'leaves',
#   'for',
#   'India',
#   'with',
#   'a',
#   'mission',
#   'at',
#   'his',
#   'hands',
#   ',',
#   'to',
#   'claim',
#   'his',
#   'lady',
#   'love',
#   'under',
#   'the',
#   'noses',
#   'of',
#   'her',
#   'whole',
#   'family',
#   '.',
#   'Thus',
#   'begins',
#   'a'],
#  ['has',
#   'left',
#   'for',
#   'India',
#   'to',
#   'be',
#   'married',
#   'to',
#   'her',
#   'childhood',
#   'fiancé',
#   '.',
#   'Raj',
#   'leaves',
#   'for',
#   'India',
#   'with',
#   'a',
#   'mission',
#   'at',
#   'his',
#   'hands',
#   ',',
#   'to',
#   'claim',
#   'his',
#   'lady',
#   'love',
#   'under',
#   'the',
#   'noses',
#   'of',
#   'her',
#   'whole',
#   'family',
#   '.',
#   'Thus',
#   'begins',
#   'a'],
#  ['left',
#   'for',
#   'India',
#   'to',
#   'be',
#   'married',
#   'to',
#   'her',
#   'childhood',
#   'fiancé',
#   '.',
#   'Raj',
#   'leaves',
#   'for',
#   'India',
#   'with',
#   'a',
#   'mission',
#   'at',
#   'his',
#   'hands',
#   ',',
#   'to',
#   'claim',
#   'his',
#   'lady',
#   'love',
#   'under',
#   'the',
#   'noses',
#   'of',
#   'her',
#   'whole',
#   'family',
#   '.',
#   'Thus',
#   'begins',
#   'a'],
#  ['be',
#   'married',
#   'to',
#   'her',
#   'childhood',
#   'fiancé',
#   '.',
#   'Raj',
#   'leaves',
#   'for',
#   'India',
#   'with',
#   'a',
#   'mission',
#   'at',
#   'his',
#   'hands',
#   ',',
#   'to',
#   'claim',
#   'his',
#   'lady',
#   'love',
#   'under',
#   'the',
#   'noses',
#   'of',
#   'her',
#   'whole',
#   'family',
#   '.',
#   'Thus',
#   'begins',
#   'a'],
#  ['leaves',
#   'for',
#   'India',
#   'with',
#   'a',
#   'mission',
#   'at',
#   'his',
#   'hands',
#   ',',
#   'to',
#   'claim',
#   'his',
#   'lady',
#   'love',
#   'under',
#   'the',
#   'noses',
#   'of',
#   'her',
#   'whole',
#   'family',
#   '.',
#   'Thus',
#   'begins',
#   'a'],
#  ['claim',
#   'his',
#   'lady',
#   'love',
#   'under',
#   'the',
#   'noses',
#   'of',
#   'her',
#   'whole',
#   'family',
#   '.',
#   'Thus',
#   'begins',
#   'a'],
#  ['is',
#   'a',
#   'rich',
#   ',',
#   'carefree',
#   ',',
#   'happy',
#   '-',
#   'go',
#   '-',
#   'lucky',
#   'second',
#   'generation',
#   'NRI',
#   '.',
#   'Simran',
#   'is',
#   'the',
#   'daughter',
#   'of',
#   'Chaudhary',
#   'Baldev',
#   'Singh',
#   ',',
#   'who',
#   'in',
#   'spite',
#   'of',
#   'being',
#   'an',
#   'NRI',
#   'is',
#   'very',
#   'strict',
#   'about',
#   'adherence',
#   'to',
#   'Indian',
#   'values',
#   '.',
#   'Simran',
#   'has',
#   'left',
#   'for',
#   'India',
#   'to',
#   'be',
#   'married',
#   'to',
#   'her',
#   'childhood',
#   'fiancé',
#   '.',
#   'Raj',
#   'leaves',
#   'for',
#   'India',
#   'with',
#   'a',
#   'mission',
#   'at',
#   'his',
#   'hands',
#   ',',
#   'to',
#   'claim',
#   'his',
#   'lady',
#   'love',
#   'under',
#   'the',
#   'noses',
#   'of',
#   'her',
#   'whole',
#   'family',
#   '.',
#   'Thus',
#   'begins',
#   'a',
#   'saga'],
#  ['go',
#   '-',
#   'lucky',
#   'second',
#   'generation',
#   'NRI',
#   '.',
#   'Simran',
#   'is',
#   'the',
#   'daughter',
#   'of',
#   'Chaudhary',
#   'Baldev',
#   'Singh',
#   ',',
#   'who',
#   'in',
#   'spite',
#   'of',
#   'being',
#   'an',
#   'NRI',
#   'is',
#   'very',
#   'strict',
#   'about',
#   'adherence',
#   'to',
#   'Indian',
#   'values',
#   '.',
#   'Simran',
#   'has',
#   'left',
#   'for',
#   'India',
#   'to',
#   'be',
#   'married',
#   'to',
#   'her',
#   'childhood',
#   'fiancé',
#   '.',
#   'Raj',
#   'leaves',
#   'for',
#   'India',
#   'with',
#   'a',
#   'mission',
#   'at',
#   'his',
#   'hands',
#   ',',
#   'to',
#   'claim',
#   'his',
#   'lady',
#   'love',
#   'under',
#   'the',
#   'noses',
#   'of',
#   'her',
#   'whole',
#   'family',
#   '.',
#   'Thus',
#   'begins',
#   'a',
#   'saga'],
#  ['is',
#   'the',
#   'daughter',
#   'of',
#   'Chaudhary',
#   'Baldev',
#   'Singh',
#   ',',
#   'who',
#   'in',
#   'spite',
#   'of',
#   'being',
#   'an',
#   'NRI',
#   'is',
#   'very',
#   'strict',
#   'about',
#   'adherence',
#   'to',
#   'Indian',
#   'values',
#   '.',
#   'Simran',
#   'has',
#   'left',
#   'for',
#   'India',
#   'to',
#   'be',
#   'married',
#   'to',
#   'her',
#   'childhood',
#   'fiancé',
#   '.',
#   'Raj',
#   'leaves',
#   'for',
#   'India',
#   'with',
#   'a',
#   'mission',
#   'at',
#   'his',
#   'hands',
#   ',',
#   'to',
#   'claim',
#   'his',
#   'lady',
#   'love',
#   'under',
#   'the',
#   'noses',
#   'of',
#   'her',
#   'whole',
#   'family',
#   '.',
#   'Thus',
#   'begins',
#   'a',
#   'saga'],
#  ['being',
#   'an',
#   'NRI',
#   'is',
#   'very',
#   'strict',
#   'about',
#   'adherence',
#   'to',
#   'Indian',
#   'values',
#   '.',
#   'Simran',
#   'has',
#   'left',
#   'for',
#   'India',
#   'to',
#   'be',
#   'married',
#   'to',
#   'her',
#   'childhood',
#   'fiancé',
#   '.',
#   'Raj',
#   'leaves',
#   'for',
#   'India',
#   'with',
#   'a',
#   'mission',
#   'at',
#   'his',
#   'hands',
#   ',',
#   'to',
#   'claim',
#   'his',
#   'lady',
#   'love',
#   'under',
#   'the',
#   'noses',
#   'of',
#   'her',
#   'whole',
#   'family',
#   '.',
#   'Thus',
#   'begins',
#   'a',
#   'saga'],
#  ['is',
#   'very',
#   'strict',
#   'about',
#   'adherence',
#   'to',
#   'Indian',
#   'values',
#   '.',
#   'Simran',
#   'has',
#   'left',
#   'for',
#   'India',
#   'to',
#   'be',
#   'married',
#   'to',
#   'her',
#   'childhood',
#   'fiancé',
#   '.',
#   'Raj',
#   'leaves',
#   'for',
#   'India',
#   'with',
#   'a',
#   'mission',
#   'at',
#   'his',
#   'hands',
#   ',',
#   'to',
#   'claim',
#   'his',
#   'lady',
#   'love',
#   'under',
#   'the',
#   'noses',
#   'of',
#   'her',
#   'whole',
#   'family',
#   '.',
#   'Thus',
#   'begins',
#   'a',
#   'saga'],
#  ['has',
#   'left',
#   'for',
#   'India',
#   'to',
#   'be',
#   'married',
#   'to',
#   'her',
#   'childhood',
#   'fiancé',
#   '.',
#   'Raj',
#   'leaves',
#   'for',
#   'India',
#   'with',
#   'a',
#   'mission',
#   'at',
#   'his',
#   'hands',
#   ',',
#   'to',
#   'claim',
#   'his',
#   'lady',
#   'love',
#   'under',
#   'the',
#   'noses',
#   'of',
#   'her',
#   'whole',
#   'family',
#   '.',
#   'Thus',
#   'begins',
#   'a',
#   'saga'],
#  ['left',
#   'for',
#   'India',
#   'to',
#   'be',
#   'married',
#   'to',
#   'her',
#   'childhood',
#   'fiancé',
#   '.',
#   'Raj',
#   'leaves',
#   'for',
#   'India',
#   'with',
#   'a',
#   'mission',
#   'at',
#   'his',
#   'hands',
#   ',',
#   'to',
#   'claim',
#   'his',
#   'lady',
#   'love',
#   'under',
#   'the',
#   'noses',
#   'of',
#   'her',
#   'whole',
#   'family',
#   '.',
#   'Thus',
#   'begins',
#   'a',
#   'saga'],
#  ['be',
#   'married',
#   'to',
#   'her',
#   'childhood',
#   'fiancé',
#   '.',
#   'Raj',
#   'leaves',
#   'for',
#   'India',
#   'with',
#   'a',
#   'mission',
#   'at',
#   'his',
#   'hands',
#   ',',
#   'to',
#   'claim',
#   'his',
#   'lady',
#   'love',
#   'under',
#   'the',
#   'noses',
#   'of',
#   'her',
#   'whole',
#   'family',
#   '.',
#   'Thus',
#   'begins',
#   'a',
#   'saga'],
#  ['leaves',
#   'for',
#   'India',
#   'with',
#   'a',
#   'mission',
#   'at',
#   'his',
#   'hands',
#   ',',
#   'to',
#   'claim',
#   'his',
#   'lady',
#   'love',
#   'under',
#   'the',
#   'noses',
#   'of',
#   'her',
#   'whole',
#   'family',
#   '.',
#   'Thus',
#   'begins',
#   'a',
#   'saga'],
#  ['claim',
#   'his',
#   'lady',
#   'love',
#   'under',
#   'the',
#   'noses',
#   'of',
#   'her',
#   'whole',
#   'family',
#   '.',
#   'Thus',
#   'begins',
#   'a',
#   'saga'],
#  ['begins', 'a', 'saga'],
#  ['is',
#   'a',
#   'rich',
#   ',',
#   'carefree',
#   ',',
#   'happy',
#   '-',
#   'go',
#   '-',
#   'lucky',
#   'second',
#   'generation',
#   'NRI',
#   '.',
#   'Simran',
#   'is',
#   'the',
#   'daughter',
#   'of',
#   'Chaudhary',
#   'Baldev',
#   'Singh',
#   ',',
#   'who',
#   'in',
#   'spite',
#   'of',
#   'being',
#   'an',
#   'NRI',
#   'is',
#   'very',
#   'strict',
#   'about',
#   'adherence',
#   'to',
#   'Indian',
#   'values',
#   '.',
#   'Simran',
#   'has',
#   'left',
#   'for',
#   'India',
#   'to',
#   'be',
#   'married',
#   'to',
#   'her',
#   'childhood',
#   'fiancé',
#   '.',
#   'Raj',
#   'leaves',
#   'for',
#   'India',
#   'with',
#   'a',
#   'mission',
#   'at',
#   'his',
#   'hands',
#   ',',
#   'to',
#   'claim',
#   'his',
#   'lady',
#   'love',
#   'under',
#   'the',
#   'noses',
#   'of',
#   'her',
#   'whole',
#   'family',
#   '.',
#   'Thus',
#   'begins',
#   'a',
#   'saga',
#   '.'],
#  ['go',
#   '-',
#   'lucky',
#   'second',
#   'generation',
#   'NRI',
#   '.',
#   'Simran',
#   'is',
#   'the',
#   'daughter',
#   'of',
#   'Chaudhary',
#   'Baldev',
#   'Singh',
#   ',',
#   'who',
#   'in',
#   'spite',
#   'of',
#   'being',
#   'an',
#   'NRI',
#   'is',
#   'very',
#   'strict',
#   'about',
#   'adherence',
#   'to',
#   'Indian',
#   'values',
#   '.',
#   'Simran',
#   'has',
#   'left',
#   'for',
#   'India',
#   'to',
#   'be',
#   'married',
#   'to',
#   'her',
#   'childhood',
#   'fiancé',
#   '.',
#   'Raj',
#   'leaves',
#   'for',
#   'India',
#   'with',
#   'a',
#   'mission',
#   'at',
#   'his',
#   'hands',
#   ',',
#   'to',
#   'claim',
#   'his',
#   'lady',
#   'love',
#   'under',
#   'the',
#   'noses',
#   'of',
#   'her',
#   'whole',
#   'family',
#   '.',
#   'Thus',
#   'begins',
#   'a',
#   'saga',
#   '.'],
#  ['is',
#   'the',
#   'daughter',
#   'of',
#   'Chaudhary',
#   'Baldev',
#   'Singh',
#   ',',
#   'who',
#   'in',
#   'spite',
#   'of',
#   'being',
#   'an',
#   'NRI',
#   'is',
#   'very',
#   'strict',
#   'about',
#   'adherence',
#   'to',
#   'Indian',
#   'values',
#   '.',
#   'Simran',
#   'has',
#   'left',
#   'for',
#   'India',
#   'to',
#   'be',
#   'married',
#   'to',
#   'her',
#   'childhood',
#   'fiancé',
#   '.',
#   'Raj',
#   'leaves',
#   'for',
#   'India',
#   'with',
#   'a',
#   'mission',
#   'at',
#   'his',
#   'hands',
#   ',',
#   'to',
#   'claim',
#   'his',
#   'lady',
#   'love',
#   'under',
#   'the',
#   'noses',
#   'of',
#   'her',
#   'whole',
#   'family',
#   '.',
#   'Thus',
#   'begins',
#   'a',
#   'saga',
#   '.'],
#  ['being',
#   'an',
#   'NRI',
#   'is',
#   'very',
#   'strict',
#   'about',
#   'adherence',
#   'to',
#   'Indian',
#   'values',
#   '.',
#   'Simran',
#   'has',
#   'left',
#   'for',
#   'India',
#   'to',
#   'be',
#   'married',
#   'to',
#   'her',
#   'childhood',
#   'fiancé',
#   '.',
#   'Raj',
#   'leaves',
#   'for',
#   'India',
#   'with',
#   'a',
#   'mission',
#   'at',
#   'his',
#   'hands',
#   ',',
#   'to',
#   'claim',
#   'his',
#   'lady',
#   'love',
#   'under',
#   'the',
#   'noses',
#   'of',
#   'her',
#   'whole',
#   'family',
#   '.',
#   'Thus',
#   'begins',
#   'a',
#   'saga',
#   '.'],
#  ['is',
#   'very',
#   'strict',
#   'about',
#   'adherence',
#   'to',
#   'Indian',
#   'values',
#   '.',
#   'Simran',
#   'has',
#   'left',
#   'for',
#   'India',
#   'to',
#   'be',
#   'married',
#   'to',
#   'her',
#   'childhood',
#   'fiancé',
#   '.',
#   'Raj',
#   'leaves',
#   'for',
#   'India',
#   'with',
#   'a',
#   'mission',
#   'at',
#   'his',
#   'hands',
#   ',',
#   'to',
#   'claim',
#   'his',
#   'lady',
#   'love',
#   'under',
#   'the',
#   'noses',
#   'of',
#   'her',
#   'whole',
#   'family',
#   '.',
#   'Thus',
#   'begins',
#   'a',
#   'saga',
#   '.'],
#  ['has',
#   'left',
#   'for',
#   'India',
#   'to',
#   'be',
#   'married',
#   'to',
#   'her',
#   'childhood',
#   'fiancé',
#   '.',
#   'Raj',
#   'leaves',
#   'for',
#   'India',
#   'with',
#   'a',
#   'mission',
#   'at',
#   'his',
#   'hands',
#   ',',
#   'to',
#   'claim',
#   'his',
#   'lady',
#   'love',
#   'under',
#   'the',
#   'noses',
#   'of',
#   'her',
#   'whole',
#   'family',
#   '.',
#   'Thus',
#   'begins',
#   'a',
#   'saga',
#   '.'],
#  ['left',
#   'for',
#   'India',
#   'to',
#   'be',
#   'married',
#   'to',
#   'her',
#   'childhood',
#   'fiancé',
#   '.',
#   'Raj',
#   'leaves',
#   'for',
#   'India',
#   'with',
#   'a',
#   'mission',
#   'at',
#   'his',
#   'hands',
#   ',',
#   'to',
#   'claim',
#   'his',
#   'lady',
#   'love',
#   'under',
#   'the',
#   'noses',
#   'of',
#   'her',
#   'whole',
#   'family',
#   '.',
#   'Thus',
#   'begins',
#   'a',
#   'saga',
#   '.'],
#  ['be',
#   'married',
#   'to',
#   'her',
#   'childhood',
#   'fiancé',
#   '.',
#   'Raj',
#   'leaves',
#   'for',
#   'India',
#   'with',
#   'a',
#   'mission',
#   'at',
#   'his',
#   'hands',
#   ',',
#   'to',
#   'claim',
#   'his',
#   'lady',
#   'love',
#   'under',
#   'the',
#   'noses',
#   'of',
#   'her',
#   'whole',
#   'family',
#   '.',
#   'Thus',
#   'begins',
#   'a',
#   'saga',
#   '.'],
#  ['leaves',
#   'for',
#   'India',
#   'with',
#   'a',
#   'mission',
#   'at',
#   'his',
#   'hands',
#   ',',
#   'to',
#   'claim',
#   'his',
#   'lady',
#   'love',
#   'under',
#   'the',
#   'noses',
#   'of',
#   'her',
#   'whole',
#   'family',
#   '.',
#   'Thus',
#   'begins',
#   'a',
#   'saga',
#   '.'],
#  ['claim',
#   'his',
#   'lady',
#   'love',
#   'under',
#   'the',
#   'noses',
#   'of',
#   'her',
#   'whole',
#   'family',
#   '.',
#   'Thus',
#   'begins',
#   'a',
#   'saga',
#   '.'],
#  ['begins', 'a', 'saga', '.'],
#  ['Framed', 'in', 'the'],
#  ['Framed', 'in', 'the', '1940s'],
#  ['Framed', 'in', 'the', '1940s', 'for'],
#  ['Framed', 'in', 'the', '1940s', 'for', 'the'],
#  ['Framed', 'in', 'the', '1940s', 'for', 'the', 'double'],
#  ['Framed', 'in', 'the', '1940s', 'for', 'the', 'double', 'murder'],
#  ['Framed', 'in', 'the', '1940s', 'for', 'the', 'double', 'murder', 'of'],
#  ['Framed',
#   'in',
#   'the',
#   '1940s',
#   'for',
#   'the',
#   'double',
#   'murder',
#   'of',
#   'his'],
#  ...]

# %%
pnounsverb = find_pattern(overview_texts,"PNounsVerb",[
        {"LABEL": ["GPE","PERSON"]},
        {"LABEL": ["GPE","PERSON"]},
        {"POS": "VERB"}    
    ]
)

# %%
pnounsverb
# Out:
# [['and', 'Potter', 'share'],
#  ['meal', ',', 'swap'],
#  ['.', 'Matt', 'be'],
#  ['charismatic', 'American', 'try'],
#  ['try', 'to', 'bring'],
#  ['bring', 'the', 'reserve'],
#  ['.', 'but', 'be'],
#  ['who', '-PRON-', 'appear'],
#  ['appear', 'to', 'be'],
#  ['a', 'woman', 'get'],
#  ['at', 'what', 'would'],
#  ['what', 'would', 'happen'],
#  ['if', '-PRON-', 'could'],
#  ['could', "'", 'block'],
#  ['happy', '-', 'go'],
#  ['.', 'Simran', 'be'],
#  ['spite', 'of', 'be'],
#  ['an', 'NRI', 'be'],
#  ['.', 'Simran', 'have'],
#  ['Simran', 'have', 'leave'],
#  ['India', 'to', 'be'],
#  ['.', 'Raj', 'leave'],
#  [',', 'to', 'claim'],
#  ['.', 'thus', 'begin'],
#  ['Andy', 'Dufresne', 'begin'],
#  ['where', '-PRON-', 'put'],
#  ['skill', 'to', 'work'],
#  [',', 'Dufresne', 'come'],
#  ['come', 'to', 'be'],
#  ['to', 'be', 'admire'],
#  ['inmate', '--', 'include'],
#  ['old', 'prisoner', 'name'],
#  ['and', 'Taki', 'be'],
#  ['complete', 'stranger', 'live'],
#  ['-PRON-', 'suddenly', 'switch'],
#  ['.', 'Mitsuha', 'wake'],
#  ['bizarre', 'occurrence', 'continue'],
#  ['continue', 'to', 'happen'],
#  ['the', 'two', 'must'],
#  ['two', 'must', 'adjust'],
#  ['.', 'when', 'organize'],
#  ['Corleone', 'barely', 'survive'],
#  [',', 'Michael', 'step'],
#  ['in', 'to', 'take'],
#  ['of', 'the', 'would'],
#  ['would', '-', 'be'],
#  ['killer', ',', 'launch'],
#  ['true', 'story', 'base'],
#  ['the', 'film', 'trace'],
#  ['father', 'who', 'train'],
#  ['daughter', 'to', 'become'],
#  ['young', 'drummer', 'begin'],
#  ['begin', 'to', 'pursue'],
#  ['Oskar', 'Schindler', 'save'],
#  ['while', '-PRON-', 'work'],
#  ['spirited', 'away', 'be'],
#  ['an', 'Oscar', 'win'],
#  ['win', 'japanese', 'animate'],
#  ['girl', 'who', 'wander'],
#  ['path', 'that', 'lead'],
#  ['a', 'world', 'rule'],
#  ['-PRON-', 'parent', 'have'],
#  ['parent', 'have', 'be'],
#  ['have', 'be', 'change'],
#  ['creature', '.', 'Will'],
#  ['-PRON-', 'ever', 'see'],
#  ['-PRON-', 'once', 'be'],
#  ['in', 'the', 'continue'],
#  ['Vito', 'Corleone', 'grow'],
#  ['Michael', 'Corleone', 'attempt'],
#  ['attempt', 'to', 'expand'],
#  ['secret', 'finally', 'come'],
#  ['as', 'someone', 'have'],
#  ['someone', 'have', 'be'],
#  ['have', 'be', 'play'],
#  ['and', 'John', 'face'],
#  ['challenge', '.', 'be'],
#  ['old', 'couple', 'visit'],
#  ['the', 'child', 'have'],
#  ['-PRON-', 'concept', 'catch'],
#  ['club', '"', 'form'],
#  ['an', 'eccentric', 'get'],
#  ['way', 'and', 'ignite'],
#  ['burger', '-', 'love'],
#  ['-', 'love', 'hit'],
#  ['drug', '-', 'addle'],
#  ['and', 'a', 'wash'],
#  ['up', 'boxer', 'converge'],
#  ['-PRON-', 'adventure', 'unfurl'],
#  ['that', 'ingeniously', 'trip'],
#  ['ancestry', 'who', 'live'],
#  ['happy', 'life', 'would'],
#  ['life', 'would', 'come'],
#  ['entire', 'family', 'be'],
#  ['family', 'be', 'deport'],
#  ['.', 'while', 'lock'],
#  ['up', '-PRON-', 'try'],
#  ['try', 'to', 'convince'],
#  ['whole', 'thing', 'be'],
#  [',', 'Batman', 'set'],
#  ['out', 'to', 'dismantle'],
#  ['dismantle', 'the', 'remain'],
#  ['organization', 'that', 'plague'],
#  ['the', 'partnership', 'prove'],
#  ['prove', 'to', 'be'],
#  ['-PRON-', 'soon', 'find'],
#  ['of', 'chaos', 'unleash'],
#  ['by', 'a', 'rise'],
#  ['criminal', 'mastermind', 'know'],
#  ['to', 'the', 'terrify'],
#  ['a', 'Tokyo', 'base'],
#  ['educator', ',', 'be'],
#  ['seaside', 'village', 'collect'],
#  ['as', '-PRON-', 'be'],
#  ['as', '-PRON-', 'have'],
#  ['-PRON-', 'have', 'miss'],
#  ['local', 'villager', 'suggest'],
#  ['that', '-PRON-', 'spend'],
#  [',', '-PRON-', 'offer'],
#  ['offer', 'to', 'find'],
#  ['place', 'to', 'stay'],
#  ['kid', 'who', 'be'],
#  ['who', 'be', 'adopt'],
#  ['age', 'and', 'climb'],
#  ['Patrick', 'McMurphy', 'inspire'],
#  ['patient', 'to', 'rebel'],
#  ['low', 'IQ', 'have'],
#  ['IQ', 'have', 'accomplish'],
#  ['life', 'and', 'be'],
#  [',', 'far', 'exceed'],
#  ['what', 'anyone', 'imagine'],
#  ['imagine', '-PRON-', 'could'],
#  ['-PRON-', 'could', 'do'],
#  ['thing', '-PRON-', 'have'],
#  ['-PRON-', 'have', 'attain'],
#  ['true', 'love', 'elude'],
#  ['Gump', "'", 'be'],
#  ['man', 'who', 'rise'],
#  ['and', 'who', 'prove'],
#  ['and', 'love', 'be'],
#  [',', 'who', 'have'],
#  ['who', 'have', 'fall'],
#  ['time', ',', 'answer'],
#  ['.', '-PRON-', 'gather'],
#  ['samurai', 'to', 'help'],
#  ['and', '-PRON-', 'teach'],
#  ['how', 'to', 'defend'],
#  ['and', '-PRON-', 'supply'],
#  ['the', 'film', 'culminate'],
#  ['40', 'bandit', 'attack'],
#  ['mother', 'bird', 'try'],
#  ['try', 'to', 'teach'],
#  ['how', 'to', 'find'],
#  [',', '-PRON-', 'encounter'],
#  ['that', '-PRON-', 'must'],
#  ['-PRON-', 'must', 'overcome'],
#  ['order', 'to', 'survive'],
#  ['John', 'Coffey', 'possess'],
#  ['power', 'to', 'heal'],
#  ['Edgecomb', ',', 'recognize'],
#  [',', '-PRON-', 'try'],
#  ['desperately', 'to', 'help'],
#  ['to', 'help', 'stave'],
#  ['off', 'the', 'condemn'],
#  ['the', 'prosecution', 'have'],
#  ['prosecution', 'have', 'rest'],
#  ['the', 'jury', 'be'],
#  ['jury', 'be', 'file'],
#  ['room', 'to', 'decide'],
#  ['-', 'american', 'be'],
#  ['innocent', 'of', 'murder'],
#  ['.', 'what', 'begin'],
#  ['open', 'and', 'shut'],
#  ['case', 'soon', 'become'],
#  [',', 'the', 'accuse'],
#  ['epic', 'saga', 'continue'],
#  ['hope', 'of', 'defeat'],
#  ['Empire', ',', 'learn'],
#  ['Jedi', 'from', 'age'],
#  ['Darth', 'Vader', 'be'],
#  ['ever', 'to', 'capture'],
#  ['and', 'R2-D2', 'be'],
#  ['R2-D2', 'be', 'throw'],
#  ['of', 'the', 'disappear'],
#  ['tribe', ',', 'be'],
#  [',', 'be', 'curse'],
#  ['by', 'a', 'demonize'],
#  ['god', 'and', 'must'],
#  ['and', 'must', 'journey'],
#  ['west', 'to', 'find'],
#  [',', '-PRON-', 'encounter'],
#  ['human', 'woman', 'fight'],
#  ['fight', 'to', 'protect'],
#  [',', 'who', 'be'],
#  ['who', 'be', 'try'],
#  ['try', 'to', 'destroy'],
#  ['.', 'Ashitaka', 'must'],
#  ['Ashitaka', 'must', 'find'],
#  ['way', 'to', 'bring'],
#  ['man', 'who', 'should'],
#  ['should', 'never', 'have'],
#  ['never', 'have', 'meet'],
#  ['aristocrat', 'who', 'be'],
#  ['who', 'be', 'injure'],
#  ['Marion', 'Crane', 'go'],
#  ['hope', 'of', 'start'],
#  [',', '-PRON-', 'end'],
#  ['Norman', 'Bates', 'care'],
#  ['the', 'place', 'seem'],
#  ['until', 'Marion', 'decide'],
#  ['decide', 'to', 'take'],
#  ['hack', 'screenwriter', 'write'],
#  ['star', 'who', 'have'],
#  ['who', 'have', 'fade'],
#  ['ballet', 'dancer', 'be'],
#  ['dancer', 'be', 'tear'],
#  ['man', '-PRON-', 'love'],
#  ['pursuit', 'to', 'become'],
#  ['something', 'terrible', 'be'],
#  ['murderous', 'plot', 'be'],
#  ['plot', 'be', 'afoot'],
#  ['ancient', 'battle', 'reach'],
#  ['of', 'reality', 'be'],
#  ['dangerous', 'past', 'come'],
#  ['back', 'to', 'haunt'],
#  ['the', 'top', 'hit'],
#  ['York', ',', 'have'],
#  [',', 'have', 'earn'],
#  ['door', 'neighbor', 'be'],
#  ['neighbor', 'be', 'wipe'],
#  [',', '-PRON-', 'become'],
#  ["'s", 'thought', 'turn'],
#  ['and', '-PRON-', 'consider'],
#  ['-PRON-', 'consider', 'follow'],
#  ['of', 'God', 'depict'],
#  ['that', 'kid', 'be'],
#  ['kid', 'be', 'carry'],
#  ['gun', 'and', 'join'],
#  ['when', '-PRON-', 'should'],
#  ['-PRON-', 'should', 'be'],
#  ['should', 'be', 'play'],
#  ['be', 'play', 'hide'],
#  ['and', '-', 'seek'],
#  ['Derek', 'Vineyard', 'be'],
#  ['Vineyard', 'be', 'parole'],
#  ['parole', 'after', 'serve'],
#  ['prison', 'for', 'kill'],
#  ['thug', 'who', 'try'],
#  ['try', 'to', 'break'],
#  ['into', '/', 'steal'],
#  [',', '-PRON-', 'learn'],
#  ['that', 'before', 'go'],
#  [',', 'Derek', 'be'],
#  ['gang', 'that', 'commit'],
#  ['action', 'greatly', 'influence'],
#  ['Danny', '.', 'reform'],
#  [',', 'Derek', 'sever'],
#  ['gang', 'and', 'become'],
#  ['determined', 'to', 'keep'],
#  ['Danny', 'from', 'go'],
#  ['as', '-PRON-', 'do'],
#  ['City', 'Lights', 'be'],
#  ['Charlie', 'Chaplin', 'direct'],
#  ['after', '-PRON-', 'establish'],
#  ['with', 'sound', 'accompany'],
#  ['the', 'film', 'be'],
#  ['man', 'who', 'fall'],
#  ['the', 'film', 'be'],
#  ['and', 'today', 'be'],
#  ['today', 'be', 'deem'],
#  ['sister', ',', 'orphan'],
#  ['-PRON-', 'mother', 'be'],
#  ['mother', 'be', 'kill'],
#  ['Tokyo', ',', 'be'],
#  [',', 'be', 'leave'],
#  ['leave', 'to', 'survive'],
#  ['in', 'what', 'remain'],
#  ['the', 'plot', 'follow'],
#  ['as', '-PRON-', 'do'],
#  ['good', 'to', 'survive'],
#  ['countryside', ',', 'battle'],
#  ['the', 'Cylons', 'launch'],
#  ['nuclear', 'attack', 'intend'],
#  ['intend', 'to', 'exterminate'],
#  ['Twelve', 'Colonies', 'be'],
#  ['Colonies', 'be', 'wipe'],
#  ['peculiar', 'neighbor', 'offer'],
#  ['widow', 'who', 'be'],
#  ['who', 'be', 'struggle'],
#  ['struggle', 'to', 'raise'],
#  ['teenager', 'who', 'be'],
#  ['a', 'filmmaker', 'recall'],
#  ['when', '-PRON-', 'fall'],
#  ['theater', 'and', 'form'],
#  ['"', 'Jeffries', 'break'],
#  ['leg', 'while', 'get'],
#  ['an', 'action', 'shoot'],
#  ['race', '.', 'confine'],
#  [',', '-PRON-', 'spend'],
#  ['-PRON-', 'time', 'look'],
#  ['rear', 'window', 'observe'],
#  ['.', '-PRON-', 'begin'],
#  ['begin', 'to', 'suspect'],
#  ['the', 'courtyard', 'may'],
#  ['courtyard', 'may', 'have'],
#  ['may', 'have', 'murder'],
#  ['.', 'Jeff', 'enlist'],
#  ['and', '-PRON-', 'visit'],
#  ['Stella', 'to', 'investigate'],
#  ['once', 'again', 'must'],
#  ['again', 'must', 'confront'],
#  ['in', 'Nakanogo', 'want'],
#  ['want', 'to', 'make'],
#  ['potter', 'Genjuro', 'intend'],
#  ['intend', 'to', 'sell'],
#  ['law', 'Tobei', 'wish'],
#  ['wish', 'to', 'become'],
#  ['respected', 'sage', 'warn'],
#  ['-PRON-', 'against', 'seek'],
#  ['-PRON-', 'advice', 'go'],
#  ['-PRON-', 'insistency', 'lead'],
#  ['century', 'Japan', 'cause'],
#  ['clan', ',', 'throw'],
#  ['samurai', 'code', 'be'],
#  ['Leonard', 'Vole', 'be'],
#  ['Vole', 'be', 'arrest'],
#  ['Wilfrid', 'Robarts', 'agree'],
#  ['agree', 'to', 'appear'],
#  ['Wilfrid', ',', 'recover'],
#  ['attack', ',', 'be'],
#  ['be', '*', 'suppose'],
#  ['*', 'to', 'be'],
#  ['criminal', 'court', 'be'],
#  ['the', 'case', 'be'],
#  ['alibi', 'witness', 'be'],
#  ['and', 'coldly', 'calculate'],
#  ["'s", 'task', 'become'],
#  ['when', 'Christine', 'agree'],
#  ['agree', 'to', 'be'],
#  ['woman', ',', 'be'],
#  [',', 'be', 'curse'],
#  ['chance', 'of', 'break'],
#  ['the', 'spell', 'lie'],
#  ['legged', ',', 'walk'],
#  ["'s", 'mother', 'die'],
#  [',', 'only', 'seem'],
#  ['seem', 'to', 'take'],
#  ['son', 'sin', 'cause'],
#  ['Yu', 'to', 'partake'],
#  ['activity', 'to', 'appease'],
#  ['.', 'this', 'be'],
#  ['the', 'Japanese', 'could'],
#  ['Japanese', 'could', 'bring'],
#  ['long', 'to', 'be'],
#  [',', 'and', 'put'],
#  ['skill', 'to', 'work'],
#  ['when', '-PRON-', 'be'],
#  ['-PRON-', 'be', 'frame'],
#  ['rival', 'for', 'steal'],
#  ['I', ',', 'command'],
#  ['Menjou', ')', 'order'],
#  [',', 'to', 'attack'],
#  ['position', ',', 'offer'],
#  ['the', 'mission', 'be'],
#  [',', 'Mireau', 'command'],
#  [',', 'to', 'plan'],
#  ['when', '-PRON-', 'end'],
#  ['General', 'Mireau', 'demand'],
#  ['order', 'to', 'save'],
#  ['Civil', 'War', 'rage'],
#  ['bandit', '–', 'comb'],
#  ['a', 'strongbox', 'contain'],
#  ['200,000', 'in', 'steal'],
#  ['shoe', 'company', 'become'],
#  ["'s", 'son', 'be'],
#  ['son', 'be', 'kidnap'],
#  ['kidnap', 'and', 'hold'],
#  ['attempt', 'to', 'convince'],
#  ['not', 'only', 'exist'],
#  [',', 'but', 'be'],
#  ['responsible', 'for', 'draw'],
#  ['heist', 'that', 'end'],
#  ['harbor', '–', 'leave'],
#  ['.', 'verbal', 'lure'],
#  ['Mr.', 'Kim', 'be'],
#  ['jobless', ',', 'lose'],
#  ['debt', 'and', 'have'],
#  ['and', 'have', 'be'],
#  ['have', 'be', 'dump'],
#  ['.', '-PRON-', 'decide'],
#  ['decide', 'to', 'end'],
#  ['all', 'by', 'jump'],
#  ['only', 'to', 'find'],
#  ['find', '-PRON-', 'wash'],
#  ['-PRON-', 'soon', 'abandon'],
#  ['rescue', 'and', 'begin'],
#  ['-PRON-', 'antic', 'catch'],
#  ['whose', 'apartment', 'overlook'],
#  ['-PRON-', 'discovery', 'change'],
#  ['the', 'Tramp', 'struggle'],
#  ['struggle', 'to', 'live'],
#  ['old', 'who', 'have'],
#  ['who', 'have', 'live'],
#  ['.', '-PRON-', 'believe'],
#  ['within', '-PRON-', 'be'],
#  ['but', 'what', 'will'],
#  ['what', 'will', 'happen'],
#  ['Ma', 'suddenly', 'tell'],
#  ['that', 'there', 'be'],
#  ['Guest', '”', 'turn'],
#  ['businessman', 'who', 'wake'],
#  ['hotel', 'room', 'lock'],
#  ['.', '-PRON-', 'hire'],
#  ['night', '-PRON-', 'work'],
#  ['together', 'to', 'clarify'],
#  ['clarify', 'what', 'happen'],
#  ['homicide', 'detective', 'be'],
#  ['whose', 'crime', 'be'],
#  ['crime', 'be', 'base'],
#  ['film', 'that', 'take'],
#  ['from', 'the', 'torture'],
#  ['.', 'Sommerset', 'research'],
#  ['effort', 'to', 'get'],
#  ['Mills', ',', 'scoff'],
#  ['effort', 'to', 'unravel'],
#  ['Aragorn', 'be', 'reveal'],
#  ['struggle', 'to', 'save'],
#  ['and', 'Sam', 'bring'],
#  ['and', 'Saoirse', 'be'],
#  ['Saoirse', 'be', 'send'],
#  ['send', 'to', 'live'],
#  ['when', '-PRON-', 'resolve'],
#  ['resolve', 'to', 'return'],
#  ['-PRON-', 'journey', 'become'],
#  ['as', '-PRON-', 'be'],
#  ['-PRON-', 'be', 'draw'],
#  ['world', 'Ben', 'know'],
#  ['but', 'this', 'be'],
#  ['fairy', 'folk', 'have'],
#  ['folk', 'have', 'be'],
#  ['-PRON-', 'soon', 'become'],
#  ['that', 'Saoirse', 'be'],
#  ['young', 'woman', 'inspire'],
#  ['God', 'to', 'lead'],
#  ['English', ',', 'be'],
#  [',', 'be', 'put'],
#  ['priest', 'who', 'try'],
#  ['try', 'to', 'force'],
#  ['-PRON-', 'to', 'confess'],
#  ['-PRON-', 'vision', 'be'],
#  ['of', 'Brothers', 'chronicle'],
#  ['rifle', 'company', 'parachute'],
#  ['of', 'Easy', 'know'],
#  ['-', 'and', 'become'],
#  ['legend', '.', 'base'],
#  ['explorer', 'who', 'make'],
#  ['a', 'newly', 'discover'],
#  ['wormhole', 'to', 'surpass'],
#  ['travel', 'and', 'conquer'],
#  ['vast', 'distance', 'involve'],
#  ['german', 'force', 'send'],
#  ['forest', 'to', 'join'],
#  ['there', '-PRON-', 'meet'],
#  [',', 'who', 'accompany'],
#  ['.', 'on', 'return'],
#  [',', 'Florya', 'find'],
#  ['fellow', 'peasant', 'massacre'],
#  ['of', 'war', 'become'],
#  ['Adenoid', 'Hynkel', 'try'],
#  ['try', 'to', 'expand'],
#  ['jewish', 'barber', 'try'],
#  ['try', 'to', 'avoid'],
#  ['english', 'teacher', 'inspire'],
#  ['student', 'to', 'rebel'],
#  ['convention', 'and', 'seize'],
#  ['day', ',', 'court'],
#  [',', 'Dounia', 'have'],
#  ['success', '.', 'support'],
#  [',', '-PRON-', 'decide'],
#  ['decide', 'to', 'follow'],
#  ['dancer', ',', 'throw'],
#  ['thief', 'who', 'commit'],
#  ['espionage', 'by', 'infiltrate'],
#  ['-PRON-', 'target', 'be'],
#  ['target', 'be', 'offer'],
#  ['chance', 'to', 'regain'],
#  ['a', 'task', 'consider'],
#  ['consider', 'to', 'be'],
#  ['event', 'that', 'take'],
#  ['hearing', '-', 'impair'],
#  ['deaf', 'student', 'be'],
#  ['victim', 'of', 'repeat'],
#  ['Princess', 'Leia', 'be'],
#  ['Leia', 'be', 'capture'],
#  ['capture', 'and', 'hold'],
#  ['effort', 'to', 'take'],
#  ['Skywalker', 'and', 'dash'],
#  ['C-3PO', 'to', 'rescue'],
#  ['princess', 'and', 'restore'],
#  ['at', 'last', 'find'],
#  ['good', 'job', 'hang'],
#  ['for', 'which', 'be'],
#  ['that', '-PRON-', 'must'],
#  ['-PRON-', 'must', 'have'],
#  ["'s", 'bicycle', 'be'],
#  ['bicycle', 'be', 'steal'],
#  ['-PRON-', 'son', 'be'],
#  ['son', 'be', 'force'],
#  ['force', 'to', 'walk'],
#  ['Leonard', 'Shelby', 'embark'],
#  ['quest', 'to', 'find'],
#  ['lowlife', 'who', 'murder'],
#  ['thriller', 'that', 'pack'],
#  ['.', 'to', 'carry'],
#  [',', 'Shelby', 'snap'],
#  ['place', ',', 'jot'],
#  ['photo', 'to', 'aid'],
#  ['search', 'and', 'jog'],
#  ['-PRON-', 'even', 'tattoo'],
#  ['bid', 'to', 'remember'],
#  ['Bud', 'Baxter', 'be'],
#  ['until', '-PRON-', 'discover'],
#  ['way', 'to', 'climb'],
#  ['.', '-PRON-', 'lend'],
#  ['place', 'to', 'take'],
#  ['-PRON-', 'often', 'have'],
#  ['have', 'to', 'deal'],
#  ['night', '-PRON-', 'be'],
#  ['-PRON-', 'be', 'leave'],
#  ['problem', 'to', 'solve'],
#  ['Sookee', ')', 'be'],
#  [')', 'be', 'hire'],
#  [')', 'who', 'live'],
#  ['the', 'maid', 'have'],
#  ['.', '-PRON-', 'be'],
#  ['a', 'pickpocket', 'recruit'],
#  ['a', 'swindler', 'pose'],
#  ['Count', 'to', 'help'],
#  ['help', '-PRON-', 'seduce'],
#  ['Lady', 'to', 'elope'],
#  ['-PRON-', ',', 'rob'],
#  [',', 'and', 'lock'],
#  ['the', 'plan', 'seem'],
#  ['seem', 'to', 'proceed'],
#  ['to', 'proceed', 'accord'],
#  ['and', 'Hideko', 'discover'],
#  ['french', 'actress', 'film'],
#  ['in', 'Hiroshima', 'have'],
#  ['as', '-PRON-', 'share'],
#  ['share', '-PRON-', 'differ'],
#  ['asylum', 'to', 'pick'],
#  ['a', 'psychiatrist', 'turn'],
#  ['.', 'Starling', 'need'],
#  ['clue', 'to', 'help'],
#  ['help', '-PRON-', 'capture'],
#  ['Lecter', 'soon', 'lead'],
#  ['deranged', 'killer', 'be'],
#  ['office', 'worker', 'find'],
#  ['paper', 'airplane', 'be'],
#  ['instrumental', 'in', 'meet'],
#  ['-PRON-', 'never', 'expect'],
#  ['a', 'boy', 'grow'],
#  ['the', '1980', 'escape'],
#  ['life', 'by', 'start'],
#  ['band', 'to', 'impress'],
#  ['girl', '-PRON-', 'like'],
#  ['greedy', 'peasant', 'escort'],
#  [',', '-PRON-', 'do'],
#  ['do', 'not', 'realize'],
#  ['-PRON-', 'companion', 'be'],
#  ['western', 'masterpiece', 'be'],
#  ['and', 'life', 'be'],
#  ['the', 'railroad', 'be'],
#  ['railroad', 'be', 'get'],
#  ['closer', 'to', 'take'],
#  ['harmonica', 'player', 'join'],
#  ['desperado', 'to', 'protect'],
#  ['the', 'pianist', 'be'],
#  ['a', 'film', 'adapt'],
#  ['world', 'war', 'live'],
#  ['live', 'and', 'hide'],
#  ['Warsaw', 'after', 'have'],
#  ['after', 'have', 'go'],
#  ['inside', 'a', 'shine'],
#  ['tiny', 'girl', 'grow'],
#  ['young', 'princess', 'enthrall'],
#  ['all', 'who', 'encounter'],
#  ['ultimately', '-PRON-', 'must'],
#  ['-PRON-', 'must', 'confront'],
#  [',', 'five', 'orphan'],
#  ['orphan', 'sister', 'live'],
#  ['-PRON-', 'family', 'prepare'],
#  ['prepare', '-PRON-', 'arrange'],
#  ['young', 'boy', 'come'],
#  ['.', 'tonight', 'be'],
#  ['and', 'Grandpa', 'be'],
#  ['Grandpa', 'be', 'take'],
#  ['-PRON-', 'to', 'work'],
#  ['boat', '-PRON-', 'row'],
#  [',', '-PRON-', 'stop'],
#  ['stop', 'and', 'wait'],
#  ['big', 'surprise', 'await'],
#  ['as', '-PRON-', 'discover'],
#  ['work', '.', 'Should'],
#  ['Should', '-PRON-', 'follow'],
#  ['Grandpa', '?', 'Will'],
#  ['Will', '-PRON-', 'be'],
#  ['able', 'to', 'find'],
#  ['botched', 'robbery', 'indicate'],
#  ['the', 'pressure', 'mount'],
#  ['.', 'crime', 'beget'],
#  ['Blonde', ',', 'bicker'],
#  ['Eddie', '--', 'unravel'],
#  ['Vincent', 'Malloy', 'dream'],
#  ['dream', 'of', 'be'],
#  ['Price', 'and', 'lose'],
#  ['daydream', 'which', 'annoy'],
#  ['when', '-PRON-', 'be'],
#  [',', 'Hotaru', 'be'],
#  ['be', 'once', 'lose'],
#  ['when', '-PRON-', 'play'],
#  ['that', '-PRON-', 'visit'],
#  [',', '-PRON-', 'have'],
#  [',', 'who', 'help'],
#  ['though', '-PRON-', 'would'],
#  ['-PRON-', 'would', 'disappear'],
#  ['human', 'being', 'touch'],
#  ['.', '-PRON-', 'begin'],
#  ['begin', 'to', 'visit'],
#  ['as', '-PRON-', 'grow'],
#  ['while', '-PRON-', 'wait'],
#  ['summer', 'to', 'come'],
#  ['together', 'to', 'flow'],
#  ['Terry', 'Malloy', 'dream'],
#  ['dream', 'about', 'be'],
#  [',', 'while', 'tend'],
#  ['pigeon', 'and', 'run'],
#  ['.', 'Terry', 'witness'],
#  ['and', 'later', 'meet'],
#  ['sister', 'and', 'feel'],
#  ['.', '-PRON-', 'introduce'],
#  [',', 'who', 'try'],
#  ['try', 'to', 'force'],
#  ['-PRON-', 'to', 'provide'],
#  ['court', 'that', 'will'],
#  ['that', 'will', 'smash'],
#  ['struggle', 'to', 'put'],
#  ['together', '-PRON-', 'shatter'],
#  ['Hertzfeldt', "'s", 'animate'],
#  ['Jack', 'Torrance', 'accept'],
#  ['Danny', ',', 'must'],
#  [',', 'must', 'live'],
#  ['must', 'live', 'isolate'],
#  ['but', '-PRON-', 'be'],
#  ['be', 'not', 'prepare'],
#  ['madness', 'that', 'lurk'],
#  ['student', ',', 'fall'],
#  ['-PRON-', 'to', 'reveal'],
#  [';', '-PRON-', 'be'],
#  ['the', 'couple', 'bear'],
#  ['daughter', '-PRON-', 'name'],
#  ['who', 'both', 'inherit'],
#  ['ability', 'to', 'transform'],
#  ['man', 'Hana', 'fall'],
#  ['with', 'suddenly', 'die'],
#  [',', '-PRON-', 'make'],
#  ['decision', 'to', 'move'],
#  ['rural', 'town', 'isolate'],
#  ['society', 'to', 'continue'],
#  ['to', 'continue', 'raise'],
#  ['War', 'veteran', 'work'],
#  ['where', 'the', 'perceive'],
#  ['and', 'sleaze', 'feed'],
#  ['action', ',', 'attempt'],
#  ['attempt', 'to', 'save'],
#  ['player', 'who', 'live'],
#  ['liner', '.', 'bear'],
#  ['bear', 'and', 'raise'],
#  ['Roth', ')', 'learn'],
#  [',', 'never', 'set'],
#  ['the', 'ship', 'may'],
#  ['ship', 'may', 'be'],
#  ['may', 'be', 'destroy'],
#  ['band', 'member', 'fear'],
#  ['that', '1900', 'may'],
#  ['may', 'still', 'be'],
#  ['willing', 'to', 'go'],
#  ['city', 'sharply', 'divide'],
#  ['between', 'the', 'work'],
#  ["'s", 'mastermind', 'fall'],
#  ['with', 'a', 'work'],
#  ['prophet', 'who', 'predict'],
#  ['savior', 'to', 'mediate'],
#  ['Toshiro', 'Mifune', 'star'],
#  ['Akira', 'Kurosawa', '’'],
#  ['.', 'to', 'rid'],
#  ['terror', '-', 'stricken'],
#  ['samurai', 'Sanjuro', 'turn'],
#  ['advantage', '.', 'remade'],
#  [',', 'this', 'exhilarate'],
#  ['-', 'twister', 'remain'],
#  ['thing', 'soon', 'turn'],
#  ['this', 'movie', 'provide'],
#  ['two', 'sister', 'move'],
#  ['order', 'to', 'be'],
#  ['to', '-PRON-', 'hospitalize'],
#  [',', 'and', 'discover'],
#  ['discover', 'the', 'surround'],
#  ['surround', 'tree', 'be'],
#  ['tree', 'be', 'inhabit'],
#  ['the', 'young', 'run'],
#  ['old', 'sister', 'seek'],
#  ['spirit', 'to', 'find'],
#  ['the', 'film', 'portray'],
#  ['nail', '-', 'bite'],
#  ['Marty', 'McFly', 'be'],
#  ['be', 'accidentally', 'send'],
#  [',', 'inadvertently', 'disrupt'],
#  ['meeting', 'and', 'attract'],
#  ['.', 'Marty', 'must'],
#  ['Marty', 'must', 'repair'],
#  ['history', 'by', 'rekindle'],
#  ['film', 'director', 'struggle'],
#  ['struggle', 'to', 'complete'],
#  ['movie', 'while', 'cope'],
#  ['how', '-PRON-', 'come'],
#  ['come', 'to', 'be'],
#  ['to', 'be', 'imprison'],
#  ['imprison', ',', 'drug'],
#  ['drug', 'and', 'torture'],
#  ['desperate', 'businessman', 'seek'],
#  ['Benjamin', 'Willard', 'be'],
#  ['Willard', 'be', 'send'],
#  [',', '"', 'do'],
#  ['do', 'not', 'exist'],
#  [',', 'nor', 'will'],
#  ['-PRON-', 'ever', 'exist'],
#  ['-PRON-', 'goal', 'be'],
#  ['be', 'to', 'locate'],
#  ['-', 'and', 'eliminate'],
#  ['Beret', 'Colonel', 'name'],
#  [',', 'who', 'have'],
#  ['who', 'have', 'be'],
#  ['have', 'be', 'lead'],
#  ['George', 'Bailey', 'have'],
#  ['Bailey', 'have', 'spend'],
#  ['entire', 'life', 'give'],
#  ['.', '-PRON-', 'have'],
#  ['have', 'always', 'long'],
#  ['long', 'to', 'travel'],
#  ['but', 'never', 'have'],
#  ['order', 'to', 'prevent'],
#  ['Potter', 'from', 'take'],
#  ['all', 'that', 'prevent'],
#  ['-PRON-', 'from', 'do'],
#  ['do', 'so', 'be'],
#  [',', 'which', 'be'],
#  ['which', 'be', 'found'],
#  ['Uncle', 'Billy', 'lose'],
#  ['8,000', 'while', 'intend'],
#  ['intend', 'to', 'deposit'],
#  ['.', 'Potter', 'find'],
#  ['money', ',', 'hide'],
#  ["'s", 'trouble', 'begin'],
#  ['Eve', 'Harrington', 'maneuver'],
#  ['child', 'murderer', 'stalk'],
#  ['exhaustive', 'investigation', 'fuel'],
#  ['the', 'police', 'have'],
#  ['police', 'have', 'be'],
#  ['unable', 'to', 'find'],
#  ['police', 'crackdown', 'make'],
#  ['underground', 'to', 'operate'],
#  ['the', 'criminal', 'decide'],
#  ['way', 'to', 'get'],
#  ['-PRON-', 'back', 'be'],
#  ['be', 'to', 'catch'],
#  ['Kid', 'also', 'make'],
#  [',', 'who', 'play'],
#  ['a', 'boy', 'care'],
#  ['when', '-PRON-', 'be'],
#  ['-PRON-', 'be', 'abandon'],
#  [',', 'Edna', 'have'],
#  ['ache', 'to', 'be'],
#  ['to', 'be', 'reunite'],
#  ['when', '-PRON-', 'find'],
#  ['-PRON-', 'and', 'wrest'],
#  [',', '-PRON-', 'make'],
#  ['for', 'what', 'turn'],
#  ['turn', 'out', 'be'],
#  ['heart', '-', 'wrench'],
#  ['scene', 'ever', 'include'],
#  [',', 'after', 'inherit'],
#  ['Bilbo', ',', 'must'],
#  [',', 'must', 'leave'],
#  ['order', 'to', 'keep'],
#  ['-PRON-', 'from', 'fall'],
#  ['a', 'fellowship', 'be'],
#  ['fellowship', 'be', 'form'],
#  ['form', 'to', 'protect'],
#  ['ringbearer', 'and', 'make'],
#  ['the', 'ring', 'arrive'],
#  ['where', '-PRON-', 'can'],
#  ['-PRON-', 'can', 'be'],
#  ['can', 'be', 'destroy'],
#  ['Oscar', '-', 'win'],
#  ['-', 'win', 'animate'],
#  ['short', 'film', 'tell'],
#  ['life', 'as', 'see'],
#  [',', 'and', 'reveal'],
#  ['meal', '-PRON-', 'share'],
#  ['Timothy', ',', 'find'],
#  ['.', '-PRON-', 'fall'],
#  ['.', 'what', 'follow'],
#  ['what', 'follow', 'show'],
#  ['burden', 'which', 'will'],
#  ['which', 'will', 'affect'],
#  ['blind', 'teenager', 'deal'],
#  ['mother', 'while', 'try'],
#  ['try', 'to', 'live'],
#  [',', '-PRON-', 'plan'],
#  ['plan', 'to', 'go'],
#  ['town', ',', 'arrive'],
#  ['new', 'feeling', 'blossom'],
#  ['in', 'Leonardo', 'make'],
#  ['make', '-PRON-', 'question'],
#  ['grow', 'up', 'can'],
#  ['up', 'can', 'be'],
#  ['and', '-PRON-', 'be'],
#  [',', 'who', 'be'],
#  ['who', 'be', 'uproot'],
#  ['-PRON-', 'father', 'start'],
#  [',', 'Riley', 'be'],
#  ['Riley', 'be', 'guide'],
#  ['the', 'emotion', 'live'],
#  ['where', '-PRON-', 'help'],
#  ['-PRON-', 'help', 'advise'],
#  ['-PRON-', 'emotion', 'struggle'],
#  ['struggle', 'to', 'adjust'],
#  ['emotion', ',', 'try'],
#  ['try', 'to', 'keep'],
#  ['best', 'to', 'navigate'],
#  ['Kanji', 'Watanabe', 'be'],
#  ['man', 'who', 'have'],
#  ['who', 'have', 'work'],
#  ['decade', '.', 'learn'],
#  ['learn', '-PRON-', 'have'],
#  [',', '-PRON-', 'start'],
#  ['start', 'to', 'look'],
#  ['man', 'wrongfully', 'accuse'],
#  ['Budapest', 'Hotel', 'tell'],
#  ['employee', 'who', 'become'],
#  ['become', '-PRON-', 'trust'],
#  ['the', 'story', 'involve'],
#  ['upheaval', 'that', 'transform'],
#  ['.', '-PRON-', 'expect'],
#  ['when', 'Presto', 'neglect'],
#  ['neglect', 'to', 'feed'],
#  ['the', 'magician', 'find'],
#  ['find', '-PRON-', 'be'],
#  ['facility', ',', 'work'],
#  [',', 'to', 'help'],
#  ['new', 'charge', 'dredge'],
#  ['tough', 'exterior', 'begin'],
#  ['exterior', 'begin', 'erode'],
#  ['Francisco', 'detective', 'suffer'],
#  ['from', 'acrophobia', 'investigate'],
#  ['the', 'while', 'become'],
#  ['Andre', 'Devigny', 'be'],
#  ['Devigny', 'be', 'imprison'],
#  [',', 'and', 'devote'],
#  ['devote', '-PRON-', 'wake'],
#  ['hour', 'to', 'plan'],
#  [',', '-PRON-', 'be'],
#  ['-PRON-', 'be', 'condemn'],
#  [',', 'and', 'give'],
#  ['cellmate', '.', 'Should'],
#  ['Should', '-PRON-', 'kill'],
#  ['or', 'risk', 'reveal'],
#  ['someone', 'who', 'may'],
#  ['who', 'may', 'be'],
#  ['little', 'girl', 'be'],
#  ['girl', 'be', 'contact'],
#  ['and', 'Sam', 'be'],
#  ['Sam', 'be', 'trek'],
#  ['Mordor', 'to', 'destroy'],
#  ['and', 'Aragorn', 'search'],
#  ['orc', '-', 'capture'],
#  ['wizard', 'Saruman', 'await'],
#  ['insane', 'general', 'start'],
#  ['general', 'frantically', 'try'],
#  ['try', 'to', 'stop'],
#  ['Mr.', 'Dietrichson', 'become'],
#  ['-PRON-', 'icily', 'calculate'],
#  ['calculate', 'wife', 'encourage'],
#  ['-PRON-', 'to', 'sign'],
#  ['indemnity', 'policy', 'propose'],
#  ['smooth', '-', 'talk'],
#  ['in', 'crime', 'plan'],
#  ['murder', 'to', 'collect'],
#  ['claim', 'manager', 'get'],
#  ['play', 'and', 'pursue'],
#  ['english', 'teacher', 'travel'],
#  ['time', 'to', 'prevent'],
#  [',', 'but', 'discover'],
#  ['discover', '-PRON-', 'be'],
#  ['-PRON-', 'be', 'attach'],
#  ['life', '-PRON-', 'have'],
#  ['-PRON-', 'have', 'make'],
#  ['a', 'boy', 'live'],
#  ['as', '-PRON-', 'be'],
#  ['-PRON-', 'be', 'look'],
#  ['back', ',', 'meet'],
#  ['Kumatetsu', 'who', 'become'],
#  ['that', 'encounter', 'lead'],
#  ['adolescent', 'who', 'delve'],
#  ['indian', 'boy', 'get'],
#  ['boy', 'get', 'lose'],
#  ['.', '-PRON-', 'survive'],
#  ['challenge', 'before', 'be'],
#  ['before', 'be', 'adopt'],
#  [',', '-PRON-', 'set'],
#  ['out', 'to', 'find'],
#  ['two', 'musician', 'witness'],
#  ['hit', 'and', 'struggle'],
#  ['struggle', 'to', 'find'],
#  ['before', '-PRON-', 'be'],
#  ['-PRON-', 'be', 'find'],
#  ['only', 'opportunity', 'be'],
#  ['be', 'to', 'join'],
#  ['as', '-PRON-', 'leave'],
#  ['.', 'to', 'make'],
#  ['getaway', '-PRON-', 'must'],
#  ['must', 'first', 'disguise'],
#  [',', 'then', 'keep'],
#  ['secret', 'and', 'deal'],
#  ['problem', 'this', 'bring'],
#  ['Foster', 'Kane', 'be'],
#  ['Kane', 'be', 'take'],
#  ['boy', 'and', 'make'],
#  ['move', '-PRON-', 'make'],
#  ['-PRON-', 'life', 'appear'],
#  ['way', 'to', 'be'],
#  ['that', 'deeply', 'wound'],
#  ['Atticus', 'Finch', 'put'],
#  ['when', '-PRON-', 'agree'],
#  ['agree', 'to', 'represent'],
#  ['black', 'man', 'accuse'],
#  ['the', 'event', 'surround'],
#  ['surround', '-PRON-', 'be'],
#  ['-PRON-', 'be', 'see'],
#  ["'s", 'trial', 'give'],
#  [',', 'there', 'be'],
#  ['ever', '-', 'strengthen'],
#  ['as', 'a', 'rampage'],
#  ["'", 'who', 'turn'],
#  ['out', 'to', 'be'],
#  ['when', '-PRON-', 'be'],
#  ['-PRON-', 'be', 'attack'],
#  ['intense', 'rivalry', 'lead'],
#  ['exchange', 'for', 'assassinate'],
#  ['Tony', 'Montana', 'stake'],
#  ['.', 'viciously', 'murder'],
#  ['anyone', 'who', 'stand'],
#  ['Tony', 'eventually', 'become'],
#  ['state', ',', 'control'],
#  ['cocaine', 'that', 'come'],
#  ['.', 'but', 'increase'],
#  ['drug', '-', 'fuel'],
#  ['fuel', 'paranoia', 'serve'],
#  ['serve', 'to', 'fuel'],
#  [',', 'a', 'wander'],
#  ['tramp', ',', 'become'],
#  ['handyman', 'and', 'fall'],
#  ['the', 'girl', 'fall'],
#  ["'s", 'versatility', 'make'],
#  ['when', '-PRON-', 'substitute'],
#  ['for', 'an', 'ail'],
#  ['.', '-PRON-', 'be'],
#  ['-PRON-', 'be', 'discharge'],
#  ['when', '-PRON-', 'protect'],
#  ['but', '-PRON-', 'return'],
#  ['performer', 'to', 'marry'],
#  ['the', 'father', 'prevail'],
#  ['-PRON-', 'to', 'rejoin'],
#  ['.', 'Charlie', 'be'],
#  ['Charlie', 'be', 'hire'],
#  ['but', '-PRON-', 'stay'],
#  ['the', 'caravan', 'move'],
#  ['german', 'submarine', 'hunt'],
#  ['submarine', 'hunt', 'ally'],
#  ['soon', '-PRON-', 'become'],
#  ['-PRON-', 'become', 'hunt'],
#  ['the', 'crew', 'try'],
#  ['try', 'to', 'survive'],
#  [',', 'while', 'stretch'],
#  ['Jacques', 'Tati', '’'],
#  ['’', 'gloriously', 'choreograph'],
#  ['of', 'technology', 'reach'],
#  [',', 'a', 'last'],
#  ['modern', 'age', 'tiptoe'],
#  ...]

# %% [markdown]
# ## Using the Root dependency
#
# First, find the root predicate, then find the entities that are directly referenced by the root.  This can be more reliable than basic pattern matching, when the sentence structure is simple, but doesn't work well for long sentences with lots of modifiers and clauses.

# %%
#For all the overviews in all the movies, find their entities, and assign them to the lowercase text.
#...this takes about 5 mins to run
def get_query_ents(span):
    return [(ent[0].i,ent[0].i+len(ent.text),ent.label_) for ent in span.ents]
def root_dependents(texts):
    matches = []
    for doc in largenlp.pipe(texts):
        for sent in doc.sents:
            predicate = None
            ents_orig = []
            for tok in sent:
                if tok.dep_ == "ROOT":
                    predicate = tok
            for ent in sent.ents:
                for tok in ent:
                    if ent.label_ in ["GPE","PERSON"] and tok.head.text==predicate.text:
                        ents_orig.append(ent)
            if(len(ents_orig)):
                lowertext = predicate.text.lower() # + '|' + sent.text
                matches.append((lowertext, {"entities":ents_orig}))
    return matches

# %%
predictate_objects = root_dependents(overview_texts)
predictate_objects
# Out:
# [('share', {'entities': [Matt]}),
#  ('is', {'entities': [Matt]}),
#  ('is', {'entities': [Simran]}),
#  ('left', {'entities': [Simran]}),
#  ('begins', {'entities': [Andy Dufresne]}),
#  ('comes', {'entities': [Dufresne]}),
#  ('are', {'entities': [Mitsuha]}),
#  ('wakes', {'entities': [Mitsuha]}),
#  ('steps', {'entities': [Michael]}),
#  ('is', {'entities': [Dangal]}),
#  ('is', {'entities': [Oscar]}),
#  ('grows', {'entities': [Vito Corleone]}),
#  ('attempts', {'entities': [Michael Corleone]}),
#  ('face', {'entities': [Sherlock]}),
#  ('sets', {'entities': [Jim Gordon]}),
#  ('is', {'entities': [Jumpei Niki]}),
#  ('inspires', {'entities': [Randle Patrick McMurphy]}),
#  ('is', {'entities': [Forrest Gump']}),
#  ('is', {'entities': [Darth Vader]}),
#  ('thrown', {'entities': [Princess Leia]}),
#  ('cursed', {'entities': [Ashitaka]}),
#  ('encounters', {'entities': [San, Lady Eboshi]}),
#  ('find', {'entities': [Ashitaka]}),
#  ('paroled', {'entities': [Derek Vineyard]}),
#  ('severs', {'entities': [Derek]}),
#  ('breaks', {'entities': [L.B. "Jeff" Jeffries]}),
#  ('enlists', {'entities': [Jeff]}),
#  ('intends', {'entities': [Genjuro]}),
#  ('agrees', {'entities': [Wilfrid Robarts]}),
#  ('supposed', {'entities': [Wilfrid]}),
#  ('orders', {'entities': [Broulard]}),
#  ('commands', {'entities': [Mireau]}),
#  ('demands', {'entities': [Mireau]}),
#  ('attempts', {'entities': [Verbal Kint]}),
#  ('is', {'entities': [Kim]}),
#  ('struggles', {'entities': [Tramp]}),
#  ('is', {'entities': [Jack]}),
#  ('revealed', {'entities': [Aragorn]}),
#  ('bring', {'entities': [Frodo]}),
#  ('sent', {'entities': [Ben]}),
#  ('put', {'entities': [Joan of Arc]}),
#  ('sends', {'entities': [Florya]}),
#  ('mironova', {'entities': [Olga Mironova, Olga Mironova]}),
#  ('finds', {'entities': [Florya]}),
#  ('tries', {'entities': [Adenoid Hynkel]}),
#  ('has', {'entities': [Dounia]}),
#  ('captured', {'entities': [Leia]}),
#  ('skywalker',
#   {'entities': [Venturesome Luke Skywalker,
#     Venturesome Luke Skywalker,
#     Venturesome Luke Skywalker]}),
#  ('finds', {'entities': [Antonio]}),
#  ('embarks', {'entities': [Leonard Shelby]}),
#  ('snaps', {'entities': [Shelby]}),
#  ('is', {'entities': [Bud Baxter]}),
#  ('hired', {'entities': [Korea]}),
#  ('needs', {'entities': [Starling]}),
#  ('dreams', {'entities': [Vincent Malloy]}),
#  ('dreams', {'entities': [Terry Malloy]}),
#  ('witnesses', {'entities': [Terry]}),
#  ('struggles', {'entities': [Bill]}),
#  ('accepts', {'entities': [Jack Torrance]}),
#  ('learned', {'entities': [Tim Roth]}),
#  ('stars', {'entities': [Toshiro Mifune, Akira Kurosawa]}),
#  ('’s', {'entities': [Yojimbo]}),
#  ('turns', {'entities': [Sanjuro]}),
#  ('sent', {'entities': [Marty McFly]}),
#  ('repair', {'entities': [Marty]}),
#  ('sent', {'entities': [Benjamin Willard]}),
#  ('spent', {'entities': [George Bailey]}),
#  ('loses', {'entities': [Uncle Billy]}),
#  ('maneuvers', {'entities': [Eve Harrington]}),
#  ('made', {'entities': [Kid]}),
#  ('has', {'entities': [Edna]}),
#  ('leave', {'entities': [Frodo Baggins]}),
#  ('is', {'entities': [Leonardo]}),
#  ('guided', {'entities': [Riley]}),
#  ('is', {'entities': [Kanji Watanabe]}),
#  ('imprisoned', {'entities': [Andre Devigny]}),
#  ('trekking', {'entities': [Frodo]}),
#  ('awaits', {'entities': [Saruman]}),
#  ('becomes', {'entities': [Dietrichson]}),
#  ('kyuta', {'entities': [Kumatetsu]}),
#  ('taken', {'entities': [Charles Foster Kane]}),
#  ('puts', {'entities': [Atticus Finch]}),
#  ('stakes', {'entities': [Tony Montana]}),
#  ('becomes', {'entities': [Tony]}),
#  ('becomes', {'entities': [Charlie]}),
#  ('hired', {'entities': [Charlie]}),
#  ('reached', {'entities': [Jacques Tati’s]}),
#  ('film', {'entities': [Akira Kurosawa]}),
#  ('appointed', {'entities': [Jefferson Smith]}),
#  ('discovers', {'entities': [Smith]}),
#  ('tries', {'entities': [Taylor]}),
#  ('find', {'entities': [Sherlock Holmes]}),
#  ('is', {'entities': [Sullivan]}),
#  ('is', {'entities': [Dave Bannion]}),
#  ('is', {'entities': [Gus]}),
#  ('manage', {'entities': [Peck]}),
#  ('is', {'entities': [Jef Costello]}),
#  ('leave', {'entities': [Milan]}),
#  ('ordered', {'entities': [Wieler]}),
#  ('heartbroken', {'entities': [Joel Barish]}),
#  ('goes', {'entities': [Alex]}),
#  ('drawn', {'entities': [Frank]}),
#  ('decides', {'entities': [Lester Burnham]}),
#  ('called', {'entities': [Rick Deckard]}),
#  ('gains', {'entities': [Plainview]}),
#  ('tasked', {'entities': [John Miller]}),
#  ('abducted', {'entities': [Solomon Northup]}),
#  ('struggles', {'entities': [Solomon]}),
#  ('is', {'entities': [Ricky]}),
#  ('meet', {'entities': [Fred C. Dobbs]}),
#  ('remains', {'entities': [Han Solo]}),
#  ('rescues', {'entities': [Luke Skywalker]}),
#  ('is', {'entities': [Mima Kirigoe]}),
#  ('send', {'entities': [Jeanne]}),
#  ('tells', {'entities': [Incendies]}),
#  ('purchases', {'entities': [Theodore]}),
#  ('finds', {'entities': [Peter Quill]}),
#  ('fight', {'entities': [Maximus]}),
#  ('cross', {'entities': [Aldo Raine]}),
#  ('speaks', {'entities': [Alma]}),
#  ('confesses', {'entities': [Alma]}),
#  ('loves',
#   {'entities': [Arturo loves Flora, Arturo loves Flora, Arturo loves Flora]}),
#  ('province', {'entities': [Gyunggi Province, Gyunggi Province]}),
#  ('hoping', {'entities': [Fernand Naudin]}),
#  ('is', {'entities': [Fernand]}),
#  ('have', {'entities': [Fernand]}),
#  ('lives', {'entities': [Jake Gittes]}),
#  ('swept', {'entities': [Gittes]}),
#  ('tells', {'entities': [Kieślowski]}),
#  ('going', {'entities': [Fred]}),
#  ('rome', {'entities': [Rome]}),
#  ('resumes', {'entities': [Rescued]}),
#  ('continue', {'entities': [Harry]}),
#  ('discovers', {'entities': [Harry]}),
#  ('discovers', {'entities': [Amélie]}),
#  ('spending', {'entities': [Amelie]}),
#  ('manages', {'entities': [Geri]}),
#  ('is', {'entities': [Roger Thornhill]}),
#  ('spends', {'entities': [Val]}),
#  ('reappears', {'entities': [Jessica]}),
#  ('raised', {'entities': [Jessica]}),
#  ('turns', {'entities': [Anna Muylaert]}),
#  ('raised', {'entities': [Douzi]}),
#  ('meets', {'entities': [Shitou]}),
#  ('becomes', {'entities': [Lawrence]}),
#  ('are', {'entities': [Don Lockwood]}),
#  ('has', {'entities': [Don]}),
#  ('brought', {'entities': [Kathy Selden]}),
#  ('bond', {'entities': [Hiro Hamada]}),
#  ('been', {'entities': [Elizabeth Taylor]}),
#  ('china', {'entities': [China]}),
#  ('forced', {'entities': [Songlian]}),
#  ('is', {'entities': [Aibileen Clark, Minny Jackson, Phelan]}),
#  ('cares', {'entities': [Jane Hudson]}),
#  ('travels', {'entities': [Isak Borg]}),
#  ('pulled', {'entities': [Tetsuo]}),
#  ('is', {'entities': [Kaneda, Tetsuo]}),
#  ('returns', {'entities': [Tom Joad]}),
#  ('takes', {'entities': [Ann]}),
#  ('finds', {'entities': [Joe]}),
#  ('assigned', {'entities': [Nascimento]}),
#  ('is', {'entities': [Jeffrey "The Dude" Lebowski]}),
#  ('is', {'entities': [Ishaan Awasthi]}),
#  ('attempting', {'entities': [Horrible]}),
#  ('outwit', {'entities': [Muska]}),
#  ('is', {'entities': [Truman Burbank]}),
#  ('allows', {'entities': [Prince Don Fabrizio Salina]}),
#  ('is', {'entities': [Walt Kowalski]}),
#  ('is', {'entities': [Kowalski]}),
#  ('is', {'entities': [Torino]}),
#  ('sets', {'entities': [Kowalski]}),
#  ('taking', {'entities': [Kowalski]}),
#  ('investigates', {'entities': [Teddy Daniels]}),
#  ('life', {'entities': [Las Vegas]}),
#  ('enabled', {'entities': [Folman]}),
#  ('tracked', {'entities': [Genya Tachibana]}),
#  ('drawn', {'entities': [Tachibana]}),
#  ('conspires', {'entities': [Washizu]}),
#  ('seems', {'entities': [Jeff Bailey]}),
#  ('dating', {'entities': [Ann Miller]}),
#  ('has', {'entities': [Jeff]}),
#  ('recruits', {'entities': [Arthur]}),
#  ('wise', {'entities': [Lancelot the Brave, Robin]}),
#  ('battles', {'entities': [Arthur]}),
#  ('works', {'entities': [Zach]}),
#  ('finds', {'entities': [Zach]}),
#  ('change', {'entities': [Tim]}),
#  ('confined', {'entities': [Antonio Salieri]}),
#  ('leaves', {'entities': [Frederico Fellini]}),
#  ('is', {'entities': [William Munny]}),
#  ('is', {'entities': [Margaret Thatcher]}),
#  ('rascal', {'entities': [Rascal]}),
#  ('joker', {'entities': [Joker]}),
#  ('dreamer', {'entities': [Dreamer]}),
#  ('stumbles', {'entities': [Llewelyn Moss]}),
#  ('enlist', {'entities': [Ripley]}),
#  ('spent', {'entities': [Carl Fredricksen]}),
#  ('is', {'entities': [Virgil Oldman]}),
#  ('allows', {'entities': [Virgil]}),
#  ('befriended', {'entities': [Zucchini]}),
#  ('learns', {'entities': [Zucchini]}),
#  ('manages', {'entities': [Akira]}),
#  ('bursting', {'entities': [Jerry]}),
#  ('enter', {'entities': [Marge]}),
#  ('has', {'entities': [Nausicaä]}),
#  ('negotiate', {'entities': [Nausicaä]}),
#  ('falls', {'entities': [Alvy Singer]}),
#  ('einem', {'entities': [Onkel Cesare]}),
#  ('schließt',
#   {'entities': [Sprengstoffanschlag ums Leben kommt,
#     Peppino sich den Kommunisten]}),
#  ('die', {'entities': [deren Hilfe]}),
#  ('die', {'entities': [Die Verantwortlichen]}),
#  ('finds', {'entities': [King Kong]}),
#  ('is', {'entities': [Bennet]}),
#  ('married', {'entities': [Steven]}),
#  ('organize', {'entities': [Pierre]}),
#  ('thinks', {'entities': [Pierre]}),
#  ('been', {'entities': [Hazel]}),
#  ('invited', {'entities': [Benjamin]}),
#  ('returns', {'entities': [Tommy Riordan]}),
#  ('keep', {'entities': [Brendan]}),
#  ('turns', {'entities': [Tony]}),
#  ('appear', {'entities': [Tony]}),
#  ('become', {'entities': [Elwood]}),
#  ('proceed', {'entities': [Gendo Ikari]}),
#  ('suffers', {'entities': [Rizwan Khan]}),
#  ('marries', {'entities': [Rizwan]}),
#  ('detained', {'entities': [Rizwan]}),
#  ('plots', {'entities': [Woody]}),
#  ('captures', {'entities': [Eddie Murphy]}),
#  ('pontificates', {'entities': [Eddie Murphy]}),
#  ('murphy', {'entities': [Eddie Murphy, Eddie Murphy]}),
#  ('coasting', {'entities': [Greg]}),
#  ('challenging', {'entities': [Astrid]}),
#  ('inspires', {'entities': [Jiro Horikoshi]}),
#  ('lives', {'entities': [Harold]}),
#  ('meets', {'entities': [Harold]}),
#  ('decides', {'entities': [Kung Fury]}),
#  ('is', {'entities': [Frankie Dunn]}),
#  ('determined', {'entities': [Maggie]}),
#  ('finds', {'entities': [Philippe Gerbier]}),
#  ('tells', {'entities': [Lee Tamahori]}),
#  ('incarcerated', {'entities': [Miklo]}),
#  ('becomes', {'entities': [Cruz]}),
#  ('becomes', {'entities': [Paco]}),
#  ('is', {'entities': [Bill Cage]}),
#  ('mesmerizes', {'entities': [Kubo]}),
#  ('forced', {'entities': [Kubo]}),
#  ('tells', {'entities': [Snatch]}),
#  ('are', {'entities': [Matt]}),
#  ('finds', {'entities': [Brian]}),
#  ('is', {'entities': [Brian]}),
#  ('leads', {'entities': [Brian]}),
#  ('is', {'entities': [Zare]}),
#  ('are', {'entities': [Rosie]}),
#  ('pursues', {'entities': [Vincent Hanna]}),
#  ('inherits', {'entities': [Victor von Frankenstein]}),
#  ('believes', {'entities': [Frankenstein]}),
#  ('is', {'entities': [Joong-ho]}),
#  ('arrive', {'entities': [Lai]}),
#  ('is', {'entities': [Chang]}),
#  ('slays', {'entities': [William Wallace]}),
#  ('jumps', {'entities': [Judy Hopps]}),
#  ('befriends', {'entities': [Bruno, Shmuel]}),
#  ('embarks', {'entities': [Bruno]}),
#  ('refuses', {'entities': [Desmond T. Doss]}),
#  ('blurs', {'entities': [Lou Bloom]}),
#  ('is', {'entities': [Nina]}),
#  ('offers', {'entities': [Peter]}),
#  ('stands', {'entities': [Germany]}),
#  ('proclaims', {'entities': [Adolf Hitler]}),
#  ('hangs', {'entities': [Lilya]}),
#  ('lost', {'entities': [Ali]}),
#  ('tied', {'entities': [Ellie Andrews]}),
#  ('jumps', {'entities': [Ellie]}),
#  ('is', {'entities': [Joker]}),
#  ('presumed', {'entities': [Mark Watney]}),
#  ('named', {'entities': [Rufus T. Firefly]}),
#  ('goes', {'entities': [Rama]}),
#  ('laid', {'entities': [Daigo]}),
#  ('struggles', {'entities': [John Nash]}),
#  ('grows', {'entities': [Nash]}),
#  ('is', {'entities': [Redmond Barry]}),
#  ('challenges', {'entities': [Barry]}),
#  ('joins', {'entities': [Barry]}),
#  ('denies', {'entities': [Sefton]}),
#  ('sent', {'entities': [Chan Wing Yan]}),
#  ('infiltrates', {'entities': [Lau Kin Ming]}),
#  ('counterparts', {'entities': [Chen Wing Yan]}),
#  ('stars', {'entities': [Libuse Safrankova]}),
#  ('fall', {'entities': [Cinderella]}),
#  ('has', {'entities': [Cinderella]}),
#  ('inspired', {'entities': [Theodor Koch-Grunberg]}),
#  ('works', {'entities': [Grace]}),
#  ('stands', {'entities': [Thomas More]}),
#  ('is', {'entities': [Ernest]}),
#  ('decides', {'entities': [Dona Hermínia]}),
#  ('prepares', {'entities': [Pike Bishop]}),
#  ('discovers', {'entities': [Bishop]}),
#  ('trails', {'entities': [Thornton]}),
#  ('are', {'entities': [Jacques]}),
#  ('harbors', {'entities': [Jacques]}),
#  ('meets', {'entities': [Jacques, Johana]}),
#  ('fall', {'entities': [Jim]}),
#  ('loves', {'entities': [Catherine]}),
#  ('starts', {'entities': [Catherine]}),
#  ('embroiled', {'entities': [Steve]}),
#  ('holes', {'entities': [Johnny Rocco]}),
#  ('saved', {'entities': [Johnny Farrell]}),
#  ('crashes', {'entities': [Paul Sheldon]}),
#  ('is', {'entities': [Annie]}),
#  ('is', {'entities': [Hubert]}),
#  ('find', {'entities': [Hubert]}),
#  ('played', {'entities': [Woody]}),
#  ('find', {'entities': [Ash Williams]}),
#  ('man', {'entities': [The Man With, The Man With, The Man With]}),
#  ('throws', {'entities': [Tracy Lord]}),
#  ('is', {'entities': [Tracy]}),
#  ('arrives', {'entities': [Dexter]}),
#  ('been', {'entities': [Edward Bloom]}),
#  ('arrives', {'entities': [Elliot Ness]}),
#  ('meets', {'entities': [Jimmy Malone]}),
#  ('asks', {'entities': [Malone]}),
#  ('return', {'entities': [Harry]}),
#  ('comes', {'entities': [Harry]}),
#  ('finds', {'entities': [Gromit]}),
#  ('is', {'entities': [Gromit]}),
#  ('fights', {'entities': [Robin Hood]}),
#  ('moves', {'entities': [Blanche DuBois]}),
#  ('supposed', {'entities': [Jim Stark]}),
#  ('forms', {'entities': [Stark]}),
#  ('is', {'entities': [Judy, Buzz]}),
#  ('wins', {'entities': [Caleb]}),
#  ('trains', {'entities': [Kenshin]}),
#  ('escapes', {'entities': [Pierrot]}),
#  ('feels', {'entities': [Ofelia]}),
#  ('complete', {'entities': [Ofelia]}),
#  ('is', {'entities': [Jamal Malik]}),
#  ('kidnaps', {'entities': [Santa Claus]}),
#  ('decides', {'entities': [Louis]}),
#  ('suggests', {'entities': [Lucy]}),
#  ('accepts', {'entities': [Charlie Brown]}),
#  ('becomes', {'entities': [Don Aguirre]}),
#  ('owns', {'entities': [Aydin]}),
#  ('struggles', {'entities': [Selma]}),
#  ('learns', {'entities': [Selma]}),
#  ('is', {'entities': [Giulia De Martino]}),
#  ('is', {'entities': [Ryota Nonomiya]}),
#  ('based', {'entities': [Bonnie]}),
#  ('covers', {'entities': [Bob Woodward]}),
#  ('hired', {'entities': [Philip Marlowe]}),
#  ('attempts', {'entities': [Rupert Pupkin]}),
#  ('resolves', {'entities': [Pepa]}),
#  ('is', {'entities': [Brazil]}),
#  ('seduced', {'entities': [Benjamin Braddock]}),
#  ('finds', {'entities': [Benjamin]}),
#  ('encounters', {'entities': [Batman, Selina Kyle]}),
#  ('depicts', {'entities': [Depicts]}),
#  ('is', {'entities': [Kyung-chul]}),
#  ('becomes', {'entities': [Joo-yeon]}),
#  ('decides', {'entities': [Soo-hyun]}),
#  ('getting', {'entities': [Sam Bell]}),
#  ('becomes', {'entities': [Taesik]}),
#  ('realizes', {'entities': [Susanna]}),
#  ('is', {'entities': [De Boeldieu]}),
#  ('play', {'entities': [Jerome Lawrence-Robert E. Lee]}),
#  ('fallen', {'entities': [Guy Foucher]}),
#  ('finds', {'entities': [Holly Golightly]}),
#  ('assumes', {'entities': [George]}),
#  ('engages', {'entities': [Bertie]}),
#  ('is', {'entities': [Bertie]}),
#  ('meets', {'entities': [Evelyn Couch, Ninny]}),
#  ('needs', {'entities': [Steele]}),
#  ('engrossed', {'entities': [Mildred Atkinson]}),
#  ('asks', {'entities': [Mildred]}),
#  ('murdered', {'entities': [Mildred]}),
#  ('tries', {'entities': [John Dunbar]}),
#  ('caught', {'entities': [Billy Hayes]}),
#  ('has', {'entities': [Hayes]}),
#  ('done', {'entities': [Butcher]}),
#  ('are', {'entities': [Anjali]}),
#  ('tries', {'entities': [Anjali]}),
#  ('fischer', {'entities': [Max Fischer, Max Fischer, Herman Blume]}),
#  ('is', {'entities': [Al Stephenson]}),
#  ('hobbled', {'entities': [Boyka]}),
#  ('hears', {'entities': [Justice Haywood]}),
#  ('is', {'entities': [Das Experiment]}),
#  ('is', {'entities': [Porco Rosso]}),
#  ('has', {'entities': [Gilbert]}),
#  ('discovers', {'entities': [Jim Garrison]}),
#  ('be', {'entities': [Uncle Charlie]}),
#  ('cares', {'entities': [Logan]}),
#  ('face', {'entities': [Han Solo]}),
#  ('uses', {'entities': [Malcolm Sayer]}),
#  ('is', {'entities': [Leonard]}),
#  ('is', {'entities': [Un Chien Andalou]}),
#  ('lives', {'entities': [Sosuke]}),
#  ('uses', {'entities': [Ponyo]}),
#  ('hired', {'entities': [Harry Caul]}),
#  ('becomes', {'entities': [Caul]}),
#  ('holds', {'entities': [J.J. Hunsecker]}),
#  ('lives', {'entities': [Shaun]}),
#  ('falls', {'entities': [Wallace]}),
#  ('set', {'entities': [Gromit]}),
#  ('is', {'entities': [Valentin]}),
#  ('finds', {'entities': [Soon Taylor, Soon Taylor]}),
#  ('leaves', {'entities': [Rahul]}),
#  ('focuses', {'entities': [Raichand]}),
#  ('permit', {'entities': [Rohan]}),
#  ('faces', {'entities': [Chris Taylor]}),
#  ('waiting', {'entities': [David Huxley]}),
#  ('meets', {'entities': [Susan Vance]}),
#  ('tells', {'entities': [Jack Crabb]}),
#  ('are', {'entities': [Georges]}),
#  ('has', {'entities': [Anne]}),
#  ('living', {'entities': [Beth]}),
#  ('overcome', {'entities': [Conrad]}),
#  ('preferred', {'entities': [Beth]}),
#  ('trapped', {'entities': [Calvin]}),
#  ('learns', {'entities': [Belle]}),
#  ('stars', {'entities': [Donnie Yen]}),
#  ('is', {'entities': [Wim Wender]}),
#  ('marries', {'entities': [Clarence, Alabama]}),
#  ('find', {'entities': [James]}),
#  ('classic', {'entities': [Hitchcock]}),
#  ('disappears', {'entities': [Froy]}),
#  ('is', {'entities': [Malik El Djebena]}),
#  ('is', {'entities': [Chow Yun-fat]}),
#  ('killed', {'entities': [Frankenstein]}),
#  ('agrees', {'entities': [Frankenstein]}),
#  ('suffers', {'entities': [Carole]}),
#  ('withdraws', {'entities': [Carole]}),
#  ('is', {'entities': [Jake Blues]}),
#  ('investigates', {'entities': [Jaime Peña]}),
#  ('find', {'entities': [Alice]}),
#  ('aspires', {'entities': [Jack Horner]}),
#  ('discovers', {'entities': [Horner, Eddie Adams]}),
#  ('accused', {'entities': [Roberto Nascimento]}),
#  ('transferred', {'entities': [Matias]}),
#  ('kidnapped', {'entities': [Souza]}),
#  ('is', {'entities': [Joseph]}),
#  ('learn', {'entities': [Jo]}),
#  ('walk', {'entities': [Harry]}),
#  ('dedicates', {'entities': [Bruce Wayne]}),
#  ('is', {'entities': [Genessier]}),
#  ('divorced', {'entities': [Hildy Johnson, Walter Burns]}),
#  ('let', {'entities': [Walter Burns]}),
#  ('heads', {'entities': [Russell]}),
#  ('picks', {'entities': [Glen]}),
#  ('feels', {'entities': [Cal Trask]}),
#  ('frustrated', {'entities': [Cal]}),
#  ('returns', {'entities': [Sam Hendrix]}),
#  ('forced', {'entities': [Lee Chandler]}),
#  ('dreams', {'entities': [Oskar]}),
#  ('befriends', {'entities': [Eli]}),
#  ('is', {'entities': [Allen]}),
#  ('delights', {'entities': [Eddie Murphy]}),
#  ('tries', {'entities': [Henry Spencer]}),
#  ('meets', {'entities': [Avanthika]}),
#  ('choose', {'entities': [Rocky Balboa]}),
#  ('sparrow', {'entities': [Jack Sparrow, Jack Sparrow]}),
#  ('receives', {'entities': [Nicholas Van Orton]}),
#  ('finds', {'entities': [Nicholas]}),
#  ('is', {'entities': [Frank Galvin]}),
#  ('reminds', {'entities': [Mickey Morrissey]}),
#  ('is', {'entities': [Sabrina Fairchild]}),
#  ('struggles', {'entities': [Seibei]}),
#  ('plays', {'entities': [Ferris Bueller]}),
#  ('houses', {'entities': [Paul Rusesabagina]}),
#  ('bauby',
#   {'entities': [Jean-Dominique Bauby,
#     Jean-Dominique Bauby,
#     Jean-Dominique Bauby,
#     Jean-Dominique Bauby]}),
#  ('described', {'entities': [Bauby]}),
#  ('meets', {'entities': [Laura Jesson, Alec Harvey]}),
#  ('plane', {'entities': [Chuck]}),
#  ('senses', {'entities': [Suzy Bannion]}),
#  ('karras', {'entities': [Damien Karras, Damien Karras]}),
#  ('lived', {'entities': [Harry Potter]}),
#  ('uncovers', {'entities': [Harry]}),
#  ('born', {'entities': [Vincent Freeman]}),
#  ('settled', {'entities': [Kenshin]}),
#  ('betrayed', {'entities': [Makoto Shishio]}),
#  ('agrees', {'entities': [Kenshin]}),
#  ('becomes', {'entities': [Ben]}),
#  ('starts', {'entities': [Harry]}),
#  ('help', {'entities': [Ron]}),
#  ('follows', {'entities': [Glengarry Glen Ross]}),
#  ('is', {'entities': [Mortimer Brewster]}),
#  ('selma', {'entities': [Selma]}),
#  ('sent', {'entities': [Jonathan Harker]}),
#  ('is', {'entities': [Count Dracula]}),
#  ('moves', {'entities': [Dracula]}),
#  ('is', {'entities': [Ben-Hur]}),
#  ('heston', {'entities': [Charlton Heston, Charlton Heston]}),
#  ('return',
#   {'entities': [The Return of the King,
#     The Return of the King,
#     The Return of the King]}),
#  ('is', {'entities': [Corey]}),
#  ('loses', {'entities': [Mikael Blomkvist]}),
#  ('continues', {'entities': [Shinji]}),
#  ('is', {'entities': [Kenji]}),
#  ('set', {'entities': [Kenji]}),
#  ('went', {'entities': [Withnail]}),
#  ('played', {'entities': [Withnail]}),
#  ('raped', {'entities': [Margaret]}),
#  ('try', {'entities': [Slevin]}),
#  ('tells', {'entities': [Neame]}),
#  ('runs', {'entities': [Franz]}),
#  ('are', {'entities': [Ray]}),
#  ('returned', {'entities': [Katniss Everdeen]}),
#  ('senses', {'entities': [Katniss]}),
#  ('pursued', {'entities': [Wales]}),
#  ('run', {'entities': [Wallace]}),
#  ('finds', {'entities': [Dorothy]}),
#  ('is', {'entities': [The Wicked Witch]}),
#  ('is', {'entities': [Doyle]}),
#  ('broken', {'entities': [Felix Ungar]}),
#  ('urged', {'entities': [Felix]}),
#  ('is', {'entities': [Felix, Oscar]}),
#  ('dreams', {'entities': [Anna]}),
#  ('accompanied', {'entities': [Olaf]}),
#  ('returns', {'entities': [Chen Zhen]}),
#  ('is', {'entities': [Floyd]}),
#  ('discusses', {'entities': [Charlie Chaplin]}),
#  ('decides', {'entities': [Nicholas Garrigan]}),
#  ('comes', {'entities': [Idi Amin]}),
#  ('blue', {'entities': [Betty Blue, Betty Blue]}),
#  ('collars', {'entities': [Harry]}),
#  ('takes', {'entities': [SEAL Chris Kyle]}),
#  ('serves', {'entities': [Kyle]}),
#  ('prompts', {'entities': [Willy Wonka]}),
#  ('have', {'entities': [Wonka]}),
#  ('is', {'entities': [Richard Hannay]}),
#  ('meets', {'entities': [Annabella Smith]}),
#  ('goes', {'entities': [Hannay]}),
#  ('flees', {'entities': [Johnny, Manchester]}),
#  ('changes', {'entities': [Briony Tallis]}),
#  ('run', {'entities': [Mikey]}),
#  ('establishes', {'entities': [Frank Lucas]}),
#  ('forced', {'entities': [Landon Carter]}),
#  ('has', {'entities': [Jamie]}),
#  ('are', {'entities': [Marty]}),
#  ('finds', {'entities': [Marty]}),
#  ('is', {'entities': [Nicholas Angel]}),
#  ('meets', {'entities': [Kathryn Railly]}),
#  ('find', {'entities': [Warrens]}),
#  ('embarks', {'entities': [Moses]}),
#  ('begins', {'entities': [Peter]}),
#  ('gets', {'entities': [Jimmy Rabbitte]}),
#  ('from', {'entities': [Wikipedia]}),
#  ('returns', {'entities': [Chen Zhen]}),
#  ('joins', {'entities': [Wyatt Earp]}),
#  ('forced', {'entities': [Earp]}),
#  ('willie', {'entities': [Willie]}),
#  ('stars', {'entities': [Laurence Olivier]}),
#  ('visited', {'entities': [Andrew]}),
#  ('professes', {'entities': [Andrew]}),
#  ('suggests', {'entities': [Andrew]}),
#  ('obtain', {'entities': [Marguerite]}),
#  ('is', {'entities': [Karl Childers]}),
#  ('deemed', {'entities': [Karl]}),
#  ('leads', {'entities': [Kirk]}),
#  ('calls', {'entities': [Cyrus]}),
#  ('given', {'entities': [Bob Parr]}),
#  ('make', {'entities': [Goku]}),
#  ('places', {'entities': [Rasputin]}),
#  ('encounters', {'entities': [Anastasia]}),
#  ('is', {'entities': [Babi]}),
#  ('is', {'entities': [Hache]}),
#  ('manufacture', {'entities': [Marko]}),
#  ('is', {'entities': [Billy Elliot]}),
#  ('leads', {'entities': [Robert Gould Shaw]}),
#  ('gunned', {'entities': [Mesrine]}),
#  ('forsakes', {'entities': [Mohandas K. Gandhi]}),
#  ('adopts', {'entities': [Gandhi]}),
#  ('asked', {'entities': [Kris Kringle]}),
#  ('is', {'entities': [Santa Claus]}),
#  ('stone', {'entities': [Ryan Stone, Ryan Stone]}),
#  ('thinks', {'entities': [Kari]}),
#  ('travels', {'entities': [P.L. Travers]}),
#  ('live', {'entities': [Arrietty]}),
#  ('creates', {'entities': [Tony Stark]}),
#  ('finds', {'entities': [Liesel]}),
#  ('seduced', {'entities': [Jep Gambardella]}),
#  ('lives', {'entities': [Weronika]}),
#  ('spot', {'entities': [Margo]}),
#  ('goes', {'entities': [Agnes]}),
#  ('tells', {'entities': [Jeffrey Wigand]}),
#  ('arrive', {'entities': [Anna Leonowens]}),
#  ('steals', {'entities': [Swan]}),
#  ('plans', {'entities': [Leach]}),
#  ('is', {'entities': [Mary Poppins]}),
#  ('places', {'entities': [Zelig]}),
#  ('named', {'entities': [Toneri Otsutsuki]}),
#  ('mount', {'entities': [Naruto]}),
#  ('struggles', {'entities': [Oliver Tate]}),
#  ('is', {'entities': [Zac Beaulieu]}),
#  ('takes', {'entities': [Zac]}),
#  ('returns', {'entities': [Nick Charles]}),
#  ('connects', {'entities': [Nick re-, Nick re-]}),
#  ('suspected', {'entities': [Clyde Wynant]}),
#  ('demoted', {'entities': [Bill Yoast]}),
#  ('is', {'entities': [Ted Kramer]}),
#  ('faced', {'entities': [Ted]}),
#  ('take', {'entities': [Joseph Kahn's]}),
#  ('taretto', {'entities': [Gustavo Taretto, Gustavo Taretto]}),
#  ('is', {'entities': [Martin]}),
#  ('is', {'entities': [Mariana]}),
#  ('are', {'entities': [Martin]}),
#  ('form', {'entities': [Jin-tae Lee]}),
#  ('are', {'entities': [Jin-tae]}),
#  ('promises', {'entities': [Jin-tae]}),
#  ('is', {'entities': [Harry]}),
#  ('takes', {'entities': [Harry]}),
#  ('asked', {'entities': [Pietro Zinni]}),
#  ('is', {'entities': [Henry Frankenstein]}),
#  ('fights', {'entities': [Grace]}),
#  ('is', {'entities': [Capturing John Lennon]}),
#  ('hits', {'entities': [Billy]}),
#  ('is', {'entities': [Butch Cassidy]}),
#  ('is', {'entities': [Jubei]}),
#  ('uses', {'entities': [Jacques Tati]}),
#  ('accepts', {'entities': [John Creasy]}),
#  ('lost', {'entities': [Trevor]}),
#  ('fisherman', {'entities': [Mende]}),
#  ('meet', {'entities': [Jesse]}),
#  ('in', {'entities': [Gu-nam]}),
#  ('wiles', {'entities': [Ha Jung-woo, Ha Jung-woo]}),
#  ('accepts', {'entities': [Gu-nam]}),
#  ('starts', {'entities': [Lee Guem-ja]}),
#  ('returns', {'entities': [Harry]}),
#  ('is', {'entities': [Charlie Simms]}),
#  ('takes', {'entities': [Charlie]}),
#  ('reconcile', {'entities': [Séverine Serizy]}),
#  ('begins', {'entities': [Séverine]}),
#  ('version', {'entities': [Franco Zeffirelli]}),
#  ('fall', {'entities': [Romeo Montague]}),
#  ('enjoys', {'entities': [Melanie Daniels]}),
#  ('leads', {'entities': [Pat Quinlan]}),
#  ('tries', {'entities': [Philip Marlowe]}),
#  ('invites', {'entities': [Lionel Twain]}),
#  ('is', {'entities': [van Helsing]}),
#  ('goes', {'entities': [Sara Crewe]}),
#  ('finds', {'entities': [Karol Karol]}),
#  ('finds', {'entities': [Ángela]}),
#  ('been', {'entities': [Don Birnam]}),
#  ('released', {'entities': [Michel]}),
#  ('is', {'entities': [Grinch]}),
#  ('hollywood', {'entities': [Hollywood]}),
#  ('is', {'entities': [Li Zhen]}),
#  ('seeks', {'entities': [Li Zhen]}),
#  ('roams', {'entities': [Henry]}),
#  ('is', {'entities': [Gabita]}),
#  ('shamed', {'entities': [Kyun-woo]}),
#  ('returns', {'entities': [Louis]}),
#  ('are', {'entities': [Spike Spiegel]}),
#  ('is', {'entities': [Christine Collins]}),
#  ('seeks', {'entities': [Deckard Shaw]}),
#  ('is', {'entities': [Chan Ka Kui]}),
#  ('frames', {'entities': [Chan]}),
#  ('is', {'entities': [Jacques Mesrine]}),
#  ('turns', {'entities': [Mentored, Mesrine]}),
#  ('sound', {'entities': [Sally Bowles]}),
#  ('chronicle', {'entities': [Alan Shepherd]}),
#  ('chard',
#   {'entities': [John Chard, John Chard, Stanley Baker, Gonville Bromhead]}),
#  ('are', {'entities': [Michael Caine]}),
#  ('meets', {'entities': [Detlef]}),
#  ('heads', {'entities': [Andy]}),
#  ('works', {'entities': [Mike Sullivan]}),
#  ('finds', {'entities': [Mike Sullivan]}),
#  ('flees', {'entities': [Lily]}),
#  ('convinced', {'entities': [Peterson]}),
#  ('brought', {'entities': [Bourne]}),
#  ('stars', {'entities': [Kirk Douglas]}),
#  ('gone', {'entities': [Bianca]}),
#  ('fixes', {'entities': [Joey, Kat]}),
#  ('discover', {'entities': [Sweethearts Brad]}),
#  ('meet', {'entities': [Brad]}),
#  ('unveils', {'entities': [Frank-N-Furter]}),
#  ('discovers', {'entities': [Zatôichi]}),
#  ('disposes', {'entities': [Ginzo]}),
#  ('enters', {'entities': [Dalton Russell]}),
#  ('assigned', {'entities': [Frazier]}),
#  ('rescued', {'entities': [Jason Bourne]}),
#  ('realizes', {'entities': [Bourne]}),
#  ('is', {'entities': [Jack Terry]}),
#  ('is', {'entities': [Francis, Marie]}),
#  ('strives', {'entities': [Gretta]}),
#  ('tessa', {'entities': [Tessa]}),
#  ('randy', {'entities': [Randy]}),
#  ('is', {'entities': [Ram" Robinson]}),
#  ('hangs', {'entities': [Randy]}),
#  ('scotland', {'entities': [Scotland]}),
#  ('teams', {'entities': [Shrek]}),
#  ('meets', {'entities': [Kay]}),
#  ('experiences', {'entities': [Marc]}),
#  ('sees', {'entities': [Marc]}),
#  ('is', {'entities': [Ove]}),
#  ('move', {'entities': [Parvaneh]}),
#  ('is', {'entities': [Jackie Brown]}),
#  ('serves', {'entities': [Rocky Balboa]}),
#  ('’s', {'entities': [Spike Jonze, Spike Jonze]}),
#  ('tells', {'entities': [Patton]}),
#  ('watched', {'entities': [Draven]}),
#  ('is', {'entities': [Frank]}),
#  ('caught', {'entities': [Tom]}),
#  ('is', {'entities': [Cecilia]}),
#  ('goes', {'entities': [Cecilia]}),
#  ('has', {'entities': [Bahia Benmahmoud]}),
#  ('meets', {'entities': [Arthur Martin]}),
#  ('awaits', {'entities': [Brendan]}),
#  ('overcome', {'entities': [Brendan]}),
#  ('succeed', {'entities': [Will Brendan, Will Brendan]}),
#  ('takes', {'entities': [Lewis Medlock]}),
#  ('returns', {'entities': [Max Rockatansky]}),
#  ('decides', {'entities': [Oshare]}),
#  ('brings', {'entities': [Gari]}),
#  ('sweet', {'entities': [Sweet, Mac]}),
#  ('investigates', {'entities': [Markway, Hill House]}),
#  ('is', {'entities': [Wadjda]}),
#  ('scheduled', {'entities': [Le Chiffre]}),
#  ('is', {'entities': [Joe Gideon]}),
#  ('agrees', {'entities': [Bambino]}),
#  ('is', {'entities': [Zhivago]}),
#  ('play', {'entities': [Omar Sharif]}),
#  ('knows', {'entities': [Beca]}),
#  ('finds', {'entities': [Beca]}),
#  ('see', {'entities': [Carraway]}),
#  ('is', {'entities': [Woody Allen]}),
#  ('has', {'entities': [Ellis Lacey]}),
#  ('is', {'entities': [Sophie]}),
#  ('discovered', {'entities': [Piaf]}),
#  ('became', {'entities': [Piaf]}),
#  ('became', {'entities': [Huo Yuan Jia]}),
#  ('faced', {'entities': [Huo]}),
#  ('resolves', {'entities': [Huo]}),
#  ('nominated', {'entities': [Meryl Streep]}),
#  ('given', {'entities': [Jack Griffin]}),
#  ('taken', {'entities': [Griffin]}),
#  ('is', {'entities': [Humbert Humbert]}),
#  ('chronicles', {'entities': [Frida]}),
#  ('lived', {'entities': [Frida Kahlo]}),
#  ('fish', {'entities': [Axel]}),
#  ('meets', {'entities': [Axel]}),
#  ('put', {'entities': [Hrundi V. Bakshi]}),
#  ('tricked', {'entities': [Hercules]}),
#  ('dies', {'entities': [Dashwood]}),
#  ('story', {'entities': [Jim Braddock]}),
#  ('surviving', {'entities': [Malcolm]}),
#  ('is', {'entities': [Santa Barbara, Dorothea Fields]}),
#  ('enlists', {'entities': [Dorothea]}),
#  ('help', {'entities': [Abbie]}),
#  ('is', {'entities': [Adam]}),
#  ('starring', {'entities': [Iko Uwais]}),
#  ('taken', {'entities': [Vegeta]}),
#  ('has', {'entities': [David Helfgott]}),
#  ('returns', {'entities': [Mark Renton]}),
#  ('notes', {'entities': [Marshall Erwin Rommel]}),
#  ('is', {'entities': [Donatella]}),
#  ('disappears', {'entities': [Amanda McCready]}),
#  ('face', {'entities': [Kenzie]}),
#  ('is', {'entities': [Scott Pilgrim]}),
#  ('is', {'entities': [Scott Pilgrim]}),
#  ("'s", {'entities': [Max]}),
#  ('furiosa', {'entities': [Furiosa]}),
#  ('continues', {'entities': [Mamoru Oshii]}),
#  ('meets', {'entities': [J.M. Barrie, Sylvia]}),
#  ('daughter', {'entities': [Nancy Thompson]}),
#  ('traces', {'entities': [Heather Langenkamp]}),
#  ('come', {'entities': [Krueger]}),
#  ('devise', {'entities': [Nancy]}),
#  ('life', {'entities': [Edmond Dantés's]}),
#  ('debate', {'entities': [Harry, Sally Will]}),
#  ('set', {'entities': [Conner]}),
#  ('threatens', {'entities': [Russell]}),
#  ('accepts', {'entities': [Bhuvan]}),
#  ('is', {'entities': [Nathan Algren]}),
#  ('city', {'entities': [New York City, New York City]}),
#  ('finds', {'entities': [Melvin Udall]}),
#  ('leave', {'entities': [Carol]}),
#  ('arrives', {'entities': [Carlos]}),
#  ('has', {'entities': [Carlos]}),
#  ('uncovers', {'entities': [Carlos]}),
#  ('won', {'entities': [Susan Sarandon, Oscar]}),
#  ('is', {'entities': [Kilian]}),
#  ('invited', {'entities': [Vincent]}),
#  ('is', {'entities': [Claude]}),
#  ('brings', {'entities': [Vincent]}),
#  ('encounters', {'entities': [William Blake]}),
#  ('become', {'entities': [Kenshin Himura]}),
#  ('comes', {'entities': [Kenshin Himura, Kaoru Kamiya]}),
#  ('opened', {'entities': [Kamiya Kasshin-ryu]}),
#  ('invites', {'entities': [Kaoru, Kenshin]}),
#  ('falls', {'entities': [Belle]}),
#  ('killed', {'entities': [Oscar]}),
#  ('is', {'entities': [Chen]}),
#  ('become', {'entities': [Chan Wing Yan]}),
#  ('led', {'entities': [Don Haskins]}),
#  ('employs', {'entities': [Rambo]}),
#  ('returned', {'entities': [Sean Thornton]}),
#  ('watched', {'entities': [Marnie]}),
#  ('has', {'entities': [Sam]}),
#  ('shames', {'entities': [Sam, Rita]}),
#  ('forced', {'entities': [Kolya]}),
#  ('receives', {'entities': [Lola]}),
#  ('picks', {'entities': [America]}),
#  ('arrives', {'entities': [Tang Lung]}),
#  ('find', {'entities': [Richard Kimble]}),
#  ('goes', {'entities': [Carl]}),
#  ('have', {'entities': [Wallace]}),
#  ('concerned', {'entities': [Gromit]}),
#  ('be', {'entities': [Gromit]}),
#  ('arrive', {'entities': [William]}),
#  ('rise', {'entities': [William]}),
#  ('convinces', {'entities': [Hedley]}),
#  ('disappears', {'entities': [Desmond]}),
#  ('hangs', {'entities': [Laura Palmer]}),
#  ('revolves', {'entities': [Sing]}),
#  ('swept', {'entities': [Joan Fontaine]}),
#  ('marries', {'entities': [Fontaine]}),
#  ('comes', {'entities': [Fontaine]}),
#  ('insisted', {'entities': [Hitchcock]}),
#  ('won', {'entities': [Fontaine]}),
#  ('embarks', {'entities': [Haru]}),
#  ('witnesses', {'entities': [Sam Bowden]}),
#  ('begins', {'entities': [Cady]}),
#  ('fly', {'entities': [Adams]}),
#  ('biopic', {'entities': [Biopic]}),
#  ('embarks', {'entities': [Michael]}),
#  ('moves', {'entities': [Scotty Smalls]}),
#  ('takes', {'entities': [Smalls]}),
#  ('staying', {'entities': [Frank Castle]}),
#  ('arrested', {'entities': [Sarah]}),
#  ('managed', {'entities': [Sarah]}),
#  ('gets', {'entities': [Julia Jarmond]}),
#  ('returns', {'entities': [Andrew]}),
#  ('joint', {'entities': [Spike Lee]}),
#  ('takes', {'entities': [Eddie]}),
#  ('grew', {'entities': [Quincy McCall]}),
#  ('meets', {'entities': [Robert]}),
#  ('recounts', {'entities': [Guevara]}),
#  ('finds', {'entities': [DJ]}),
#  ('continues', {'entities': [Karan]}),
#  ('is', {'entities': [Aslam]}),
#  ('sukhi', {'entities': [Sukhi]}),
#  ('pandey', {'entities': [Laxman Pandey, Laxman Pandey]}),
#  ('adopts', {'entities': [Damien]}),
#  ('made', {'entities': [Columbus]}),
#  ('have', {'entities': [Tallahassee]}),
#  ('finds', {'entities': [Luxo Jr.]}),
#  ('is', {'entities': [Young Rhoda Penmark]}),
#  ('suspects', {'entities': [Rhoda]}),
#  ('adopts', {'entities': [Teena Brandon]}),
#  ('goes', {'entities': [AWOL]}),
#  ('went', {'entities': [Ray Charles]}),
#  ('bets', {'entities': [Cleopatra]}),
#  ('calls', {'entities': [Edifis]}),
#  ('understands', {'entities': [Greg]}),
#  ('grew', {'entities': [Rudy]}),
#  ('is', {'entities': [Charlie]}),
#  ('defies', {'entities': [Diana]}),
#  ('hires', {'entities': [Eddie Valiant]}),
#  ('has', {'entities': [Young Elin]}),
#  ('is', {'entities': [Agnes]}),
#  ('ends', {'entities': [Elin]}),
#  ('avoids', {'entities': [Elin, Agnes]}),
#  ('are', {'entities': [Polly Bailey]}),
#  ('is', {'entities': [Ortolan Finistirre]}),
#  ('is', {'entities': [Nick]}),
#  ('struggles', {'entities': [Llewyn Davis]}),
#  ('caught', {'entities': [Wong Fei-Hong]}),
#  ('fight', {'entities': [Fei-Hong]}),
#  ('heads', {'entities': [Claude]}),
#  ('developed', {'entities': [Ted Striker]}),
#  ('receives', {'entities': [Susan Morrow]}),
#  ('remained', {'entities': [Nixon]}),
#  ('surprised', {'entities': [Nixon]}),
#  ('misadventures', {'entities': [Gonzo]}),
#  ('find', {'entities': [Diane]}),
#  ('shoots', {'entities': [Louise]}),
#  ('captures', {'entities': [Soviet Union, Francis Gary Powers]}),
#  ('is', {'entities': [James Donovan]}),
#  ('boards', {'entities': [Donovan]}),
#  ('get', {'entities': [Rudolf Abel]}),
#  ('jentsch', {'entities': [Julia Jentsch, Julia Jentsch]}),
#  ('creates', {'entities': [Marc Rothemund]}),
#  ('is', {'entities': [Charlestown]}),
#  ('released', {'entities': [Billy]}),
#  ('kidnaps', {'entities': [Layla]}),
#  ('harboring', {'entities': [Aman]}),
#  ('south', {'entities': [South]}),
#  ('put', {'entities': [Juan]}),
#  ('works', {'entities': [Kowalski]}),
#  ('sets', {'entities': [Mattie Ross]}),
#  ('hires', {'entities': [Reuben J. "Rooster" Cogburn]}),
#  ('insists', {'entities': [Mattie]}),
#  ('marries', {'entities': [Humbert Humbert]}),
#  ('assigned', {'entities': [Will Montgomery, Will Montgomery]}),
#  ('decides', {'entities': [Zinos]}),
#  ('gambles', {'entities': [Illias]}),
#  ('becomes', {'entities': [Leela]}),
#  ('is', {'entities': [Harold]}),
#  ('returns', {'entities': [Jason]}),
#  ('risks', {'entities': [Danny]}),
#  ('encounters', {'entities': [Xixo]}),
#  ('works', {'entities': [Young-Goon]}),
#  ('gets', {'entities': [Young-Goon]}),
#  ('form', {'entities': [Young-Goon]}),
#  ('becomes', {'entities': [Young-Goon]}),
#  ('believe', {'entities': [Young-Goon]}),
#  ('plays', {'entities': [Kitano, Murakawa]}),
#  ('hit', {'entities': [Paul Benjamin]}),
#  ('saves', {'entities': [Rashid Cole]}),
#  ('moved', {'entities': [Paul]}),
#  ('starred', {'entities': [Jodie Foster]}),
#  ('is', {'entities': [Mark Zuckerberg]}),
#  ('lives', {'entities': [Villainous Gru]}),
#  ('explodes',
#   {'entities': [George Clooney - explodes, George Clooney - explodes]}),
#  ('is', {'entities': [Harold Crick]}),
#  ('find', {'entities': [Harold]}),
#  ('called', {'entities': [Neil Howie]}),
#  ('realizes', {'entities': [Jim]}),
#  ('been', {'entities': [Bob]}),
#  ('attempts', {'entities': [Gus Van Sant]}),
#  ('are', {'entities': [Benedick]}),
#  ('opens', {'entities': [Ip]}),
#  ('wayne', {'entities': [Bruce Wayne, Bruce Wayne]}),
#  ('england', {'entities': [England, America]}),
#  ('save', {'entities': [Will Maximus, Will Maximus]}),
#  ('are', {'entities': [Norman Thayer]}),
#  ('plays', {'entities': [Denzel Washington, McCall]}),
#  ('comes', {'entities': [McCall]}),
#  ('meets', {'entities': [Erika Kohut]}),
#  ('ask', {'entities': [Lars]}),
#  ('is', {'entities': [Lars]}),
#  ('given', {'entities': [Pierre Michel]}),
#  ('plunges', {'entities': [Pierre]}),
#  ('was', {'entities': [Mathilde]}),
#  ('refuses', {'entities': [Mathilde]}),
#  ('is', {'entities': [Mathilde]}),
#  ('arrives', {'entities': [Ben Sanderson]}),
#  ('wakes', {'entities': [Colter Stevens]}),
#  ('lives', {'entities': [Colter]}),
#  ('lives', {'entities': [Rebecca]}),
#  ('paid', {'entities': [Dylan]}),
#  ('was', {'entities': [Tarzan]}),
#  ('make', {'entities': [Tarzan]}),
#  ('arrives', {'entities': [Newt Scamander]}),
#  ('given', {'entities': [Uthur Pendragon]}),
#  ('buries', {'entities': [Uthur]}),
#  ('sires', {'entities': [Morgana]}),
#  ('discovered', {'entities': [Ben Whittaker]}),
#  ('move', {'entities': [Emad]}),
#  ('captures', {'entities': [Morris Stanley, Charlie Burns]}),
#  ('buy', {'entities': [Sidney]}),
#  ('choose', {'entities': [Norville Barnes]}),
#  ('anderson', {'entities': [Wes Anderson, Wes Anderson]}),
#  ('go', {'entities': [Chris]}),
#  ('reads', {'entities': [Chris]}),
#  ('film', {'entities': [Hitchcock]}),
#  ('leaves', {'entities': [Ali, Belgium]}),
#  ('finds', {'entities': [Victor Pivert]}),
#  ('ends', {'entities': [Pivert]}),
#  ('persuaded', {'entities': [Kermit the Frog, Kermit the Frog]}),
#  ('picks', {'entities': [Kermit, Fozzie Bear]}),
#  ('elude', {'entities': [Kermit]}),
#  ('leaves', {'entities': [Adelaide Bonfamille]}),
#  ('left', {'entities': [Ada McGrath]}),
#  ('sold', {'entities': [Ada]}),
#  ('becomes', {'entities': [Ada]}),
#  ('forced', {'entities': [Justine]}),
#  ('take', {'entities': [Ethan]}),
#  ('finds', {'entities': [Joe Toy]}),
#  ('is', {'entities': [Ray Kinsella]}),
#  ('develops', {'entities': [Jean-Baptiste Grenouille]}),
#  ('partners', {'entities': [Brian O'Conner]}),
#  ('andree', {'entities': [Stacie Andree, Stacie Andree]}),
#  ('is', {'entities': [Natalie]}),
#  ('walk', {'entities': [Cora]}),
#  ('follow', {'entities': [Sarah]}),
#  ('realize', {'entities': [Stitch]}),
#  ('wants', {'entities': [Jack Beauregard]}),
#  ('live', {'entities': [Sara]}),
#  ('stop', {'entities': [Harry]}),
#  ('poland', {'entities': [Poland]}),
#  ('is', {'entities': [Anna]}),
#  ('tells', {'entities': [Wanda, Anna]}),
#  ('forced', {'entities': [Napoleon Solo]}),
#  ('is', {'entities': [Ralph]}),
#  ('escapes', {'entities': [Ralph]}),
#  ('meets', {'entities': [Ralph, Vanellope von Schweetz]}),
#  ('steals', {'entities': [Vandal Savage]}),
#  ('is', {'entities': [John Anderton]}),
#  ('becomes', {'entities': [Anderton]}),
#  ('lives', {'entities': [Hobbs]}),
#  ('is', {'entities': [Clark Griswold]}),
#  ('head', {'entities': [Priscilla]}),
#  ('transferred', {'entities': [Eric]}),
#  ('approached', {'entities': [Eric]}),
#  ('finds', {'entities': [Eric]}),
#  ('flees', {'entities': [Matt Buckner]}),
#  ('learns', {'entities': [Matt]}),
#  ('reprise', {'entities': [Nero]}),
#  ('convinced', {'entities': [Cao, Han]}),
#  ('admitted', {'entities': [Tony]}),
#  ...]
